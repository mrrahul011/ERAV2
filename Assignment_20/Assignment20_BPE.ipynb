# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ERA_V2/Assignment20/
# Out:
# /content/drive/MyDrive/ERA_V2/Assignment20

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# read it in to inspect it
with open('malayalam_input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
print("length of dataset in characters: ", len(text))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# length of dataset in characters:  383879

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ജോലിയില്‍ നിന്ന് ഒരു ബ്രേക്ക് എടുക്കുന്നതിനു മുന്‍പ്..
# കമ്ബോളങ്ങള്‍ കരടിയുടെ പിടിയില്‍
# കൊച്ചി മെട്രോയുടെ ബ്രാന്‍ഡ് അംബാസിഡറായി നടന്‍ സുരേഷ് ഗോപിയെ നിയമിച്ചു
# ഇന്ധനവിലയില്‍ വീണ്ടും വര്‍ദ്ധനവ്, പെട്രോളിന് 14 പൈസയും ഡീസലിന് 15 പൈസയും വര്‍ദ്ധിച്ചു
# ഫെഡറേഷന്‍ കപ്പ‌് അത‌്‌ലറ്റിക‌്സിന‌് ഇന്ന‌് തുടക്കം
# ഓഹരി സൂചികകള്‍ നേട്ടത്തില്‍;  196 പോയന്റില്‍ ക്ലോസ് ചെയ്തു
# കോഹ്ലിയെ വീഴ്ത്തുന്നതിങ്ങനെ ; തന്ത്രം വെളിപ്പെടുത്തി ഷെയിന്‍ വോണ്‍
# ഗ്ലാമറായി പ്രിയാ വാര്യര്‍; ശ്രീദേവി ബംഗ്ലാവിലെ ലൊക്കേഷന്‍ ചിത്രങ്ങള്‍ വൈറലാകുന്നു
# ഇന്ത്യ , ഇംഗ്ലണ്ട്‌ രണ്ടാം വനിതാ ട്വന്റി 20 യില്‍ ഇംഗ്ലണ്ടിന്‌ 5 വിക്കറ്റ്‌ ജയം
# അനില്‍ അംബാനിയുടെ ജാമ്യാപേക്ഷ കോടതി തള്ളി; എറിക്​സണ് 453 കോടി നല്‍കണം എന്ന് സുപ്രീംകോടതി
# എം എസ് ധോണിയുടെ ഹെലികോപ്‌ടര്‍ ഷോട്ടില്‍ ഐപിഎല്‍ പരിശീലനത്തിന് തുടക്കം കുറിച്ച്‌ ഹാര്‍ദ്ദിക് പാണ്ഡ്യ
# ലൈഫ് ഇന്‍ഷുറന്‍സ് പ്രീമിയം ഏപ്രില്‍ മുതല്‍ കുറയും
# ബിഹാറിനെ ഇളക്കിമറിക്കാന്‍ കോണ്‍ഗ്രസ്; രാഹുലിന്റെ വിളികാത്ത് പ്രമുഖരുടെ പട, ഇത്തവണ പൊടിപാറും
# ആദ്യ സീസണില്‍ തന്നെ ഐലീഗില്‍ മൂന്നാം സ്ഥാനം സ്വന്തമാക്കി റിയല്‍ കാശ്മീര്‍
# 48.2 ഓവറിലെ ട

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#  !"%&'()+,-./0123456789:;=?@[]`ംഃഅആഇഈഉഊഋഎഏഐഒഓഔകഖഗഘങചഛജഞടഠഡഢണതഥദധനപഫബഭമയരറലളഴവശഷസഹാിീുൂൃെേൈൊോൌ്ൗ൪​‌‍
# 100

# %% [markdown]
# ## using regex to remove the patterns {[!"%&\'()+,-./0123456789:;=?@\[\]]}

# %%
import regex as re
pattern = r'[!"%&\'()+,-./0123456789:;=?@\[\]]'
text = re.sub(pattern, '', text)
print(text[:1000])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ജോലിയില്‍ നിന്ന് ഒരു ബ്രേക്ക് എടുക്കുന്നതിനു മുന്‍പ്
# കമ്ബോളങ്ങള്‍ കരടിയുടെ പിടിയില്‍
# കൊച്ചി മെട്രോയുടെ ബ്രാന്‍ഡ് അംബാസിഡറായി നടന്‍ സുരേഷ് ഗോപിയെ നിയമിച്ചു
# ഇന്ധനവിലയില്‍ വീണ്ടും വര്‍ദ്ധനവ് പെട്രോളിന്  പൈസയും ഡീസലിന്  പൈസയും വര്‍ദ്ധിച്ചു
# ഫെഡറേഷന്‍ കപ്പ‌് അത‌്‌ലറ്റിക‌്സിന‌് ഇന്ന‌് തുടക്കം
# ഓഹരി സൂചികകള്‍ നേട്ടത്തില്‍   പോയന്റില്‍ ക്ലോസ് ചെയ്തു
# കോഹ്ലിയെ വീഴ്ത്തുന്നതിങ്ങനെ  തന്ത്രം വെളിപ്പെടുത്തി ഷെയിന്‍ വോണ്‍
# ഗ്ലാമറായി പ്രിയാ വാര്യര്‍ ശ്രീദേവി ബംഗ്ലാവിലെ ലൊക്കേഷന്‍ ചിത്രങ്ങള്‍ വൈറലാകുന്നു
# ഇന്ത്യ  ഇംഗ്ലണ്ട്‌ രണ്ടാം വനിതാ ട്വന്റി  യില്‍ ഇംഗ്ലണ്ടിന്‌  വിക്കറ്റ്‌ ജയം
# അനില്‍ അംബാനിയുടെ ജാമ്യാപേക്ഷ കോടതി തള്ളി എറിക്​സണ്  കോടി നല്‍കണം എന്ന് സുപ്രീംകോടതി
# എം എസ് ധോണിയുടെ ഹെലികോപ്‌ടര്‍ ഷോട്ടില്‍ ഐപിഎല്‍ പരിശീലനത്തിന് തുടക്കം കുറിച്ച്‌ ഹാര്‍ദ്ദിക് പാണ്ഡ്യ
# ലൈഫ് ഇന്‍ഷുറന്‍സ് പ്രീമിയം ഏപ്രില്‍ മുതല്‍ കുറയും
# ബിഹാറിനെ ഇളക്കിമറിക്കാന്‍ കോണ്‍ഗ്രസ് രാഹുലിന്റെ വിളികാത്ത് പ്രമുഖരുടെ പട ഇത്തവണ പൊടിപാറും
# ആദ്യ സീസണില്‍ തന്നെ ഐലീഗില്‍ മൂന്നാം സ്ഥാനം സ്വന്തമാക്കി റിയല്‍ കാശ്മീര്‍
#  ഓവറിലെ ട്വിസ്റ്റ് ഇന്നലെയും ഇന്ത്യന

# %% [markdown]
# ## save to new text file

# %%
with open('malayalam.txt', 'w', encoding='utf-8') as f:
  f.write(text)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#  `ംഃഅആഇഈഉഊഋഎഏഐഒഓഔകഖഗഘങചഛജഞടഠഡഢണതഥദധനപഫബഭമയരറലളഴവശഷസഹാിീുൂൃെേൈൊോൌ്ൗ൪​‌‍
# 71

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

print(encode("ലൈഫ് ഇന്‍ഷുറന്‍സ് പ്രീമിയം"))
print(decode(encode("ലൈഫ് ഇന്‍ഷുറന്‍സ് പ്രീമിയം")))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [45, 61, 38, 65, 1, 7, 36, 65, 70, 50, 56, 44, 36, 65, 70, 51, 65, 1, 37, 65, 43, 55, 41, 54, 42, 3]
# ലൈഫ് ഇന്‍ഷുറന്‍സ് പ്രീമിയം

# %%
ord("ഇ")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 3335

# %%
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print('---')
print(text[:200])
print("text length:", len(text))
print('---')
print(tokens[:200])
print("token length:", len(tokens))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ---
# ജോലിയില്‍ നിന്ന് ഒരു ബ്രേക്ക് എടുക്കുന്നതിനു മുന്‍പ്
# കമ്ബോളങ്ങള്‍ കരടിയുടെ പിടിയില്‍
# കൊച്ചി മെട്രോയുടെ ബ്രാന്‍ഡ് അംബാസിഡറായി നടന്‍ സുരേഷ് ഗോപിയെ നിയമിച്ചു
# ഇന്ധനവിലയില്‍ വീണ്ടും വര്‍ദ്ധനവ് പെട്രോളിന്
# text length: 374738
# ---
# [224, 180, 156, 224, 181, 139, 224, 180, 178, 224, 180, 191, 224, 180, 175, 224, 180, 191, 224, 180, 178, 224, 181, 141, 226, 128, 141, 32, 224, 180, 168, 224, 180, 191, 224, 180, 168, 224, 181, 141, 224, 180, 168, 224, 181, 141, 32, 224, 180, 146, 224, 180, 176, 224, 181, 129, 32, 224, 180, 172, 224, 181, 141, 224, 180, 176, 224, 181, 135, 224, 180, 149, 224, 181, 141, 224, 180, 149, 224, 181, 141, 32, 224, 180, 142, 224, 180, 159, 224, 181, 129, 224, 180, 149, 224, 181, 141, 224, 180, 149, 224, 181, 129, 224, 180, 168, 224, 181, 141, 224, 180, 168, 224, 180, 164, 224, 180, 191, 224, 180, 168, 224, 181, 129, 32, 224, 180, 174, 224, 181, 129, 224, 180, 168, 224, 181, 141, 226, 128, 141, 224, 180, 170, 224, 181, 141, 10, 224, 180, 149, 224, 180, 174, 224, 181, 141, 224, 180, 172, 224, 181, 139, 224, 180, 179, 224, 180, 153, 224, 181, 141, 224, 180, 153, 224, 180, 179, 224, 181, 141, 226, 128, 141, 32, 224, 180, 149, 224, 180, 176, 224, 180, 159, 224, 180, 191, 224, 180, 175, 224]
# token length: 1043456

# %% [markdown]
# ## Find pair of bytes that occur most commonly and then replace them

# %%
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]): # Pythonic way to iterate consecutive elements
        counts[pair] = counts.get(pair, 0) + 1
    return counts

stats = get_stats(tokens)
print(stats)
print(sorted(((v,k) for k,v in stats.items()), reverse=True))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# {(224, 180): 222741, (180, 156): 1633, (156, 224): 1567, (224, 181): 92201, (181, 139): 4836, (139, 224): 7663, (180, 178): 10236, (178, 224): 9629, (180, 191): 25301, (191, 224): 20127, (180, 175): 11793, (175, 224): 10297, (181, 141): 57718, (141, 226): 14385, (226, 128): 19417, (128, 141): 12537, (141, 32): 14166, (32, 224): 33777, (180, 168): 18193, (168, 224): 17491, (141, 224): 39995, (180, 146): 495, (146, 224): 474, (180, 176): 13719, (176, 224): 13289, (181, 129): 12799, (129, 32): 1083, (180, 172): 2225, (172, 224): 2184, (181, 135): 3093, (135, 224): 4480, (180, 149): 17894, (149, 224): 17474, (180, 142): 1445, (142, 224): 1321, (180, 159): 9746, (159, 224): 9528, (129, 224): 10639, (180, 164): 13880, (164, 224): 13538, (180, 174): 7297, (174, 224): 7140, (180, 170): 9213, (170, 224): 8973, (141, 10): 1709, (10, 224): 4940, (180, 179): 3778, (179, 224): 3491, (180, 153): 2998, (153, 224): 2984, (181, 134): 7184, (134, 32): 3519, (181, 138): 858, (138, 224): 843, (180, 154): 5052, (154, 224): 4859, (191, 32): 3858, (134, 224): 4623, (180, 190): 12192, (190, 224): 11544, (180, 161): 1513, (161, 224): 1477, (180, 133): 1526, (133, 224): 1485, (180, 130): 6628, (130, 224): 2716, (180, 184): 7502, (184, 224): 7388, (180, 177): 8359, (177, 224): 8182, (180, 183): 1951, (183, 224): 1835, (180, 151): 1639, (151, 224): 1815, (129, 10): 828, (180, 135): 1747, (180, 167): 1143, (167, 224): 1107, (180, 181): 7804, (181, 224): 7655, (181, 128): 2794, (128, 224): 2659, (180, 163): 3813, (163, 224): 3662, (130, 32): 4523, (180, 166): 1998, (166, 224): 1930, (32, 32): 1422, (181, 136): 838, (136, 224): 804, (180, 171): 1013, (171, 224): 990, (170, 226): 83, (128, 140): 1743, (140, 224): 1038, (164, 226): 64, (149, 226): 135, (168, 226): 66, (130, 10): 968, (180, 147): 516, (147, 224): 496, (180, 185): 1264, (185, 224): 1225, (181, 130): 1689, (180, 180): 626, (180, 224): 597, (190, 32): 266, (180, 182): 1394, (182, 224): 1314, (175, 32): 1300, (140, 32): 652, (183, 32): 76, (128, 139): 5137, (191, 10): 692, (180, 144): 304, (144, 224): 190, (175, 10): 81, (180, 143): 343, (143, 224): 332, (180, 150): 321, (150, 224): 301, (159, 32): 141, (163, 32): 118, (180, 134): 1217, (180, 165): 387, (165, 224): 352, (10, 32): 89, (168, 32): 594, (177, 32): 93, (136, 32): 157, (134, 10): 102, (178, 32): 487, (170, 10): 58, (176, 32): 301, (135, 32): 174, (180, 173): 674, (173, 224): 654, (139, 226): 1691, (191, 226): 623, (190, 226): 371, (181, 226): 77, (179, 226): 21, (130, 226): 110, (143, 226): 11, (180, 137): 427, (137, 224): 408, (156, 10): 6, (181, 10): 12, (139, 32): 529, (149, 32): 269, (138, 32): 6, (172, 10): 1, (128, 32): 40, (164, 32): 261, (180, 158): 1156, (158, 224): 1112, (168, 10): 42, (179, 32): 252, (180, 131): 7, (131, 224): 153, (167, 32): 26, (154, 32): 172, (184, 10): 10, (144, 32): 98, (179, 10): 14, (171, 226): 9, (128, 226): 95, (180, 136): 164, (136, 226): 38, (156, 226): 30, (180, 226): 6, (175, 226): 115, (185, 32): 21, (139, 10): 101, (140, 10): 44, (181, 131): 162, (134, 226): 157, (142, 226): 66, (135, 226): 171, (178, 226): 48, (172, 226): 33, (177, 226): 67, (129, 226): 249, (185, 226): 12, (181, 151): 221, (151, 226): 32, (32, 226): 61, (180, 160): 27, (160, 224): 26, (174, 10): 24, (32, 10): 82, (180, 152): 108, (152, 224): 105, (183, 226): 32, (147, 226): 20, (161, 226): 18, (135, 10): 15, (180, 32): 20, (170, 32): 103, (158, 32): 44, (178, 10): 71, (159, 226): 64, (166, 226): 20, (140, 226): 14, (174, 32): 85, (180, 155): 40, (155, 224): 40, (176, 10): 28, (174, 226): 48, (182, 32): 52, (184, 226): 60, (166, 32): 43, (181, 32): 60, (184, 32): 44, (165, 32): 31, (180, 148): 14, (148, 224): 14, (167, 226): 10, (164, 10): 17, (176, 226): 101, (182, 226): 23, (159, 10): 13, (142, 32): 57, (137, 226): 19, (154, 226): 13, (138, 226): 17, (150, 32): 14, (156, 32): 30, (161, 32): 14, (133, 226): 41, (163, 226): 23, (163, 10): 10, (180, 139): 11, (180, 162): 7, (162, 224): 7, (144, 10): 8, (10, 226): 5, (153, 226): ...
# [(222741, (224, 180)), (92201, (224, 181)), (57718, (181, 141)), (39995, (141, 224)), (33777, (32, 224)), (25301, (180, 191)), (20127, (191, 224)), (19417, (226, 128)), (18193, (180, 168)), (17894, (180, 149)), (17491, (168, 224)), (17474, (149, 224)), (14385, (141, 226)), (14166, (141, 32)), (13880, (180, 164)), (13719, (180, 176)), (13538, (164, 224)), (13289, (176, 224)), (12799, (181, 129)), (12537, (128, 141)), (12192, (180, 190)), (11793, (180, 175)), (11544, (190, 224)), (10639, (129, 224)), (10297, (175, 224)), (10236, (180, 178)), (9746, (180, 159)), (9629, (178, 224)), (9528, (159, 224)), (9213, (180, 170)), (8973, (170, 224)), (8359, (180, 177)), (8182, (177, 224)), (7804, (180, 181)), (7663, (139, 224)), (7655, (181, 224)), (7502, (180, 184)), (7388, (184, 224)), (7297, (180, 174)), (7184, (181, 134)), (7140, (174, 224)), (6628, (180, 130)), (5137, (128, 139)), (5052, (180, 154)), (4940, (10, 224)), (4859, (154, 224)), (4836, (181, 139)), (4623, (134, 224)), (4523, (130, 32)), (4480, (135, 224)), (3858, (191, 32)), (3813, (180, 163)), (3778, (180, 179)), (3662, (163, 224)), (3519, (134, 32)), (3491, (179, 224)), (3093, (181, 135)), (2998, (180, 153)), (2984, (153, 224)), (2794, (181, 128)), (2716, (130, 224)), (2659, (128, 224)), (2225, (180, 172)), (2184, (172, 224)), (1998, (180, 166)), (1951, (180, 183)), (1930, (166, 224)), (1835, (183, 224)), (1815, (151, 224)), (1747, (180, 135)), (1743, (128, 140)), (1709, (141, 10)), (1691, (139, 226)), (1689, (181, 130)), (1639, (180, 151)), (1633, (180, 156)), (1567, (156, 224)), (1526, (180, 133)), (1513, (180, 161)), (1485, (133, 224)), (1477, (161, 224)), (1445, (180, 142)), (1422, (32, 32)), (1394, (180, 182)), (1321, (142, 224)), (1314, (182, 224)), (1300, (175, 32)), (1264, (180, 185)), (1225, (185, 224)), (1217, (180, 134)), (1156, (180, 158)), (1143, (180, 167)), (1112, (158, 224)), (1107, (167, 224)), (1083, (129, 32)), (1038, (140, 224)), (1013, (180, 171)), (990, (171, 224)), (968, (130, 10)), (858, (181, 138)), (843, (138, 224)), (838, (181, 136)), (828, (129, 10)), (804, (136, 224)), (692, (191, 10)), (674, (180, 173)), (654, (173, 224)), (652, (140, 32)), (626, (180, 180)), (623, (191, 226)), (597, (180, 224)), (594, (168, 32)), (529, (139, 32)), (516, (180, 147)), (496, (147, 224)), (495, (180, 146)), (487, (178, 32)), (474, (146, 224)), (427, (180, 137)), (408, (137, 224)), (387, (180, 165)), (371, (190, 226)), (352, (165, 224)), (343, (180, 143)), (332, (143, 224)), (321, (180, 150)), (304, (180, 144)), (301, (176, 32)), (301, (150, 224)), (269, (149, 32)), (266, (190, 32)), (261, (164, 32)), (252, (179, 32)), (249, (129, 226)), (221, (181, 151)), (190, (144, 224)), (174, (135, 32)), (172, (154, 32)), (171, (135, 226)), (164, (180, 136)), (162, (181, 131)), (157, (136, 32)), (157, (134, 226)), (153, (131, 224)), (141, (159, 32)), (135, (149, 226)), (118, (163, 32)), (115, (175, 226)), (110, (130, 226)), (108, (180, 152)), (105, (152, 224)), (103, (170, 32)), (102, (134, 10)), (101, (176, 226)), (101, (139, 10)), (98, (144, 32)), (95, (128, 226)), (93, (177, 32)), (89, (10, 32)), (85, (174, 32)), (83, (170, 226)), (82, (32, 10)), (81, (175, 10)), (77, (181, 226)), (76, (183, 32)), (71, (178, 10)), (67, (177, 226)), (66, (168, 226)), (66, (142, 226)), (64, (164, 226)), (64, (159, 226)), (61, (32, 226)), (60, (184, 226)), (60, (181, 32)), (58, (170, 10)), (57, (142, 32)), (52, (182, 32)), (48, (178, 226)), (48, (174, 226)), (44, (184, 32)), (44, (158, 32)), (44, (140, 10)), (43, (166, 32)), (42, (168, 10)), (41, (133, 226)), (40, (180, 155)), (40, (155, 224)), (40, (128, 32)), (38, (136, 226)), (33, (172, 226)), (32, (183, 226)), (32, (151, 226)), (31, (165, 32)), (30, (156, 226)), (30, (156, 32)), (28, (176, 10)), (27, (180, 160)), (26, (167, 32)), (26, (160, 224)), (24, (174, 10)), (23, (182, 226)), (23, (163, 226)), (21, (185, 32)), (21, (179, 226)), (20, (180, 32)), (20, (166, 226)), (20, (147, 226)), (19, (137, 226)), (18, (161, 226)), (17, (177, 10)),  ...

# %%
top_pair = max(stats, key=stats.get)
top_pair
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# (224, 180)

# %%
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# ---
vocab_size = 5000 # the desired final vocabulary size
num_merges = vocab_size - 256
ids = list(tokens) # copy so we don't destroy the original list

merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  print(f"merging {pair} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# merging (224, 180) into a new token 256
# merging (224, 181) into a new token 257
# merging (257, 141) into a new token 258
# merging (258, 256) into a new token 259
# merging (32, 256) into a new token 260
# merging (256, 191) into a new token 261
# merging (261, 256) into a new token 262
# merging (226, 128) into a new token 263
# merging (258, 263) into a new token 264
# merging (257, 129) into a new token 265
# merging (264, 141) into a new token 266
# merging (256, 190) into a new token 267
# merging (267, 256) into a new token 268
# merging (265, 256) into a new token 269
# merging (139, 256) into a new token 270
# merging (257, 134) into a new token 271
# merging (256, 168) into a new token 272
# merging (258, 260) into a new token 273
# merging (266, 260) into a new token 274
# merging (256, 176) into a new token 275
# merging (149, 259) into a new token 276
# merging (256, 164) into a new token 277
# merging (259, 164) into a new token 278
# merging (10, 256) into a new token 279
# merging (276, 149) into a new token 280
# merging (130, 260) into a new token 281
# merging (262, 178) into a new token 282
# merging (257, 270) into a new token 283
# merging (266, 256) into a new token 284
# merging (256, 175) into a new token 285
# merging (261, 260) into a new token 286
# merging (263, 270) into a new token 287
# merging (271, 260) into a new token 288
# merging (259, 177) into a new token 289
# merging (257, 135) into a new token 290
# merging (262, 175) into a new token 291
# merging (259, 159) into a new token 292
# merging (259, 168) into a new token 293
# merging (259, 176) into a new token 294
# merging (257, 128) into a new token 295
# merging (262, 168) into a new token 296
# merging (256, 159) into a new token 297
# merging (256, 178) into a new token 298
# merging (277, 278) into a new token 299
# merging (256, 184) into a new token 300
# merging (259, 175) into a new token 301
# merging (256, 179) into a new token 302
# merging (256, 281) into a new token 303
# merging (256, 163) into a new token 304
# merging (256, 177) into a new token 305
# merging (256, 174) into a new token 306
# merging (259, 154) into a new token 307
# merging (256, 181) into a new token 308
# merging (282, 274) into a new token 309
# merging (268, 168) into a new token 310
# merging (256, 170) into a new token 311
# merging (268, 176) into a new token 312
# merging (153, 259) into a new token 313
# merging (269, 281) into a new token 314
# merging (259, 170) into a new token 315
# merging (264, 140) into a new token 316
# merging (257, 130) into a new token 317
# merging (154, 307) into a new token 318
# merging (256, 149) into a new token 319
# merging (263, 139) into a new token 320
# merging (268, 175) into a new token 321
# merging (256, 130) into a new token 322
# merging (272, 293) into a new token 323
# merging (256, 280) into a new token 324
# merging (32, 260) into a new token 325
# merging (275, 284) into a new token 326
# merging (269, 159) into a new token 327
# merging (262, 280) into a new token 328
# merging (313, 153) into a new token 329
# merging (269, 168) into a new token 330
# merging (181, 262) into a new token 331
# merging (262, 318) into a new token 332
# merging (330, 293) into a new token 333
# merging (272, 274) into a new token 334
# merging (269, 164) into a new token 335
# merging (272, 278) into a new token 336
# merging (259, 178) into a new token 337
# merging (262, 176) into a new token 338
# merging (265, 260) into a new token 339
# merging (256, 329) into a new token 340
# merging (159, 292) into a new token 341
# merging (269, 174) into a new token 342
# merging (275, 274) into a new token 343
# merging (320, 287) into a new token 344
# merging (290, 256) into a new token 345
# merging (266, 279) into a new token 346
# merging (257, 138) into a new token 347
# merging (327, 288) into a new token 348
# merging (257, 136) into a new token 349
# merging (262, 164) into a new token 350
# merging (262, 149) into a new token 351
# merging (269, 177) into a new token 352
# merging (304, 292) into a new token 353
# merging (321, 286) into a new token 354
# merging (311, 315) into a new token 355
# merging (170, 294) into a new token 356
# merging (297, 292) into a new token 357
# merging (257, 139) into a new token 358
# merging (265, 279) into a new token 359
# merging (305, 289) into a new token 360
# merging (170, 315) into a new token 361
# merging (256, 166) into a new token 362
# merging (258, 279) into a new token 363
# merging (289, 289) into a new token 364
# merging (271, 285) into a new token 365
# merging (291, 260) into a new token 366
# merging (256, 151) into a new token 367
# merging (316, 260) into a new token 368
# merging (310, 274) into a new token 369
# merging (336, 301) into a new token 370
# merging (261, 279) into a new token 371
# merging (135, 370) into a new token 372
# merging (269, 149) into a new token 373
# merging (256, 276) into a new token 374
# merging (268, 178) into a new token 375
# merging (340, 302) into a new token 376
# merging (273, 170) into a new token 377
# merging (289, 288) into a new token 378
# merging (259, 172) into a new token 379
# merging (273, 149) into a new token 380
# merging (259, 174) into a new token 381
# merging (181, 295) into a new token 382
# merging (260, 149) into a new token 383
# merging (268, 163) into a new token 384
# merging (271, 323) into a new token 385
# merging (269, 130) into a new token 386
# merging (260, 184) into a new token 387
# merging (259, 181) into a new token 388
# merging (272, 284) into a new token 389
# merging (320, 344) into a new token 390
# merging (350, 294) into a new token 391
# merging (256, 158) into a new token 392
# merging (298, 274) into a new token 393
# merging (261, 287) into a new token 394
# merging (177, 289) into a new token 395
# merging (273, 174) into a new token 396
# merging (283, 159) into a new token 397
# merging (260, 170) into a new token 398
# merging (256, 161) into a new token 399
# merging (184, 364) into a new token 400
# merging (258, 325) into a new token 401
# merging (269, 181) into a new token 402
# merging (296, 378) into a new token 403
# merging (156, 285) into a new token 404
# merging (268, 164) into a new token 405
# merging (273, 184) into a new token 406
# merging (260, 181) into a new token 407
# merging (373, 302) into a new token 408
# merging (322, 279) into a new token 409
# merging (268, 280) into a new token 410
# merging (154, 391) into a new token 411
# merging (352, 299) into a new token 412
# merging (282, 337) into a new token 413
# merging (300, 273) into a new token 414
# merging (256, 172) into a new token 415
# merging (335, 366) into a new token 416
# merging (284, 280) into a new token 417
# merging (256, 185) into a new token 418
# merging (313, 149) into a new token 419
# merging (283, 179) into a new token 420
# merging (374, 183) into a new token 421
# merging (332, 368) into a new token 422
# merging (342, 354) into a new token 423
# merging (170, 283) into a new token 424
# merging (345, 183) into a new token 425
# merging (275, 266) into a new token 426
# merging (283, 163) into a new token 427
# merging (260, 168) into a new token 428
# merging (259, 158) into a new token 429
# merging (273, 164) into a new token 430
# merging (273, 168) into a new token 431
# merging (262, 361) into a new token 432
# merging (282, 288) into a new token 433
# merging (170, 416) into a new token 434
# merging (256, 173) into a new token 435
# merging (290, 324) into a new token 436
# merging (170, 412) into a new token 437
# merging (259, 179) into a new token 438
# merging (256, 318) into a new token 439
# merging (299, 296) into a new token 440
# merging (259, 280) into a new token 441
# merging (299, 309) into a new token 442
# merging (273, 181) into a new token 443
# merging (260, 174) into a new token 444
# merging (256, 180) into a new token 445
# merging (285, 309) into a new token 446
# merging (259, 184) into a new token 447
# merging (386, 279) into a new token 448
# merging (256, 182) into a new token 449
# merging (298, 284) into a new token 450
# merging (291, 348) into a new token 451
# merging (271, 297) into a new token 452
# merging (335, 278) into a new token 453
# merging (303, 149) into a new token 454
# merging (259, 166) into a new token 455
# merging (259, 167) into a new token 456
# merging (312, 284) into a new token 457
# merging (262, 184) into a new token 458
# merging (273, 133) into a new token 459
# merging (262, 181) into a new token 460
# merging (268, 281) into a new token 461
# merging (283, 185) into a new token 462
# merging (262, 174) into a new token 463
# merging (306, 379) into a new token 464
# merging (268, 174) into a new token 465
# merging (358, 260) into a new token 466
# merging (298, 337) into a new token 467
# merging (267, 287) into a new token 468
# merging (172, 268) into a new token 469
# merging (275, 268) into a new token 470
# merging (283, 176) into a new token 471
# merging (159, 295) into a new token 472
# merging (268, 184) into a new token 473
# merging (259, 165) into a new token 474
# merging (322, 367) into a new token 475
# merging (256, 183) into a new token 476
# merging (286, 149) into a new token 477
# merging (269, 179) into a new token 478
# merging (290, 275) into a new token 479
# merging (328, 333) into a new token 480
# merging (268, 179) into a new token 481
# merging (268, 181) into a new token 482
# merging (285, 441) into a new token 483
# merging (154, 365) into a new token 484
# merging (260, 164) into a new token 485
# merging (285, 348) into a new token 486
# merging (277, 338) into a new token 487
# merging (296, 293) into a new token 488
# merging (376, 274) into a new token 489
# merging (268, 149) into a new token 490
# merging (392, 429) into a new token 491
# merging (331, 341) into a new token 492
# merging (286, 184) into a new token 493
# merging (256, 171) into a new token 494
# merging (269, 176) into a new token 495
# merging (284, 161) into a new token 496
# merging (283, 149) into a new token 497
# merging (316, 300) into a new token 498
# merging (257, 151) into a new token 499
# merging (262, 159) into a new token 500
# merging (372, 334) into a new token 501
# merging (306, 381) into a new token 502
# merging (176, 268) into a new token 503
# merging (170, 275) into a new token 504
# merging (326, 280) into a new token 505
# merging (146, 275) into a new token 506
# merging (273, 142) into a new token 507
# merging (269, 280) into a new token 508
# merging (287, 168) into a new token 509
# merging (291, 309) into a new token 510
# merging (268, 170) into a new token 511
# merging (478, 438) into a new token 512
# merging (351, 302) into a new token 513
# merging (273, 134) into a new token 514
# merging (256, 156) into a new token 515
# merging (176, 317) into a new token 516
# merging (256, 419) into a new token 517
# merging (272, 289) into a new token 518
# merging (399, 291) into a new token 519
# merging (319, 275) into a new token 520
# merging (269, 492) into a new token 521
# merging (269, 163) into a new token 522
# merging (10, 272) into a new token 523
# merging (286, 168) into a new token 524
# merging (283, 341) into a new token 525
# merging (262, 341) into a new token 526
# merging (282, 346) into a new token 527
# merging (271, 487) into a new token 528
# merging (271, 357) into a new token 529
# merging (426, 299) into a new token 530
# merging (282, 436) into a new token 531
# merging (184, 388) into a new token 532
# merging (266, 325) into a new token 533
# merging (147, 300) into a new token 534
# merging (272, 455) into a new token 535
# merging (400, 343) into a new token 536
# merging (273, 135) into a new token 537
# merging (516, 311) into a new token 538
# merging (382, 353) into a new token 539
# merging (389, 184) into a new token 540
# merging (164, 312) into a new token 541
# merging (174, 268) into a new token 542
# merging (437, 521) into a new token 543
# merging (170, 304) into a new token 544
# merging (287, 176) into a new token 545
# merging (273, 178) into a new token 546
# merging (262, 130) into a new token 547
# merging (288, 149) into a new token 548
# merging (285, 314) into a new token 549
# merging (375, 274) into a new token 550
# merging (408, 274) into a new token 551
# merging (539, 314) into a new token 552
# merging (271, 299) into a new token 553
# merging (262, 142) into a new token 554
# merging (295, 414) into a new token 555
# merging (392, 307) into a new token 556
# merging (294, 295) into a new token 557
# merging (312, 274) into a new token 558
# merging (159, 294) into a new token 559
# merging (333, 359) into a new token 560
# merging (326, 163) into a new token 561
# merging (259, 163) into a new token 562
# merging (284, 177) into a new token 563
# merging (257, 131) into a new token 564
# merging (268, 130) into a new token 565
# merging (286, 181) into a new token 566
# merging (262, 182) into a new token 567
# merging (269, 178) into a new token 568
# merging (133, 308) into a new token 569
# merging (300, 364) into a new token 570
# merging (284, 184) into a new token 571
# merging (303, 168) into a new token 572
# merging (424, 536) into a new token 573
# merging (265, 287) into a new token 574
# merging (331, 404) into a new token 575
# merging (349, 272) into a new token 576
# merging (312, 301) into a new token 577
# merging (317, 357) into a new token 578
# merging (382, 519) into a new token 579
# merging (268, 166) into a new token 580
# merging (283, 178) into a new token 581
# merging (345, 182) into a new token 582
# merging (320, 390) into a new token 583
# merging (256, 167) into a new token 584
# merging (261, 325) into a new token 585
# merging (474, 310) into a new token 586
# merging (317, 297) into a new token 587
# merging (543, 359) into a new token 588
# merging (283, 175) into a new token 589
# merging (296, 288) into a new token 590
# merging (262, 177) into a new token 591
# merging (262, 395) into a new token 592
# merging (290, 353) into a new token 593
# merging (452, 453) into a new token 594
# merging (262, 171) into a new token 595
# merging (10, 277) into a new token 596
# merging (256, 142) into a new token 597
# merging (333, 339) into a new token 598
# merging (303, 184) into a new token 599
# merging (273, 182) into a new token 600
# merging (276, 176) into a new token 601
# merging (295, 300) into a new token 602
# merging (266, 287) into a new token 603
# merging (286, 170) into a new token 604
# merging (167, 427) into a new token 605
# merging (164, 327) into a new token 606
# merging (276, 183) into a new token 607
# merging (142, 323) into a new token 608
# merging (305, 291) into a new token 609
# merging (135, 272) into a new token 610
# merging (271, 324) into a new token 611
# merging (338, 332) into a new token 612
# merging (269, 170) into a new token 613
# merging (317, 275) into a new token 614
# merging (420, 274) into a new token 615
# merging (362, 296) into a new token 616
# merging (333, 277) into a new token 617
# merging (168, 297) into a new token 618
# merging (286, 174) into a new token 619
# merging (290, 357) into a new token 620
# merging (284, 181) into a new token 621
# merging (256, 154) into a new token 622
# merging (269, 361) into a new token 623
# merging (356, 277) into a new token 624
# merging (276, 175) into a new token 625
# merging (134, 275) into a new token 626
# merging (362, 301) into a new token 627
# merging (472, 306) into a new token 628
# merging (184, 322) into a new token 629
# merging (303, 170) into a new token 630
# merging (143, 319) into a new token 631
# merging (319, 302) into a new token 632
# merging (308, 272) into a new token 633
# merging (328, 360) into a new token 634
# merging (290, 298) into a new token 635
# merging (528, 288) into a new token 636
# merging (385, 273) into a new token 637
# merging (301, 511) into a new token 638
# merging (450, 149) into a new token 639
# merging (268, 177) into a new token 640
# merging (283, 166) into a new token 641
# merging (295, 275) into a new token 642
# merging (295, 367) into a new token 643
# merging (303, 174) into a new token 644
# merging (322, 325) into a new token 645
# merging (314, 149) into a new token 646
# merging (535, 294) into a new token 647
# merging (181, 271) into a new token 648
# merging (181, 275) into a new token 649
# merging (469, 419) into a new token 650
# merging (484, 278) into a new token 651
# merging (133, 272) into a new token 652
# merging (547, 367) into a new token 653
# merging (322, 435) into a new token 654
# merging (304, 562) into a new token 655
# merging (506, 339) into a new token 656
# merging (563, 288) into a new token 657
# merging (631, 616) into a new token 658
# merging (177, 282) into a new token 659
# merging (151, 294) into a new token 660
# merging (266, 299) into a new token 661
# merging (326, 183) into a new token 662
# merging (317, 355) into a new token 663
# merging (178, 497) into a new token 664
# merging (176, 353) into a new token 665
# merging (181, 268) into a new token 666
# merging (484, 301) into a new token 667
# merging (332, 359) into a new token 668
# merging (149, 397) into a new token 669
# merging (273, 172) into a new token 670
# merging (405, 294) into a new token 671
# merging (304, 274) into a new token 672
# merging (336, 294) into a new token 673
# merging (331, 544) into a new token 674
# merging (347, 275) into a new token 675
# merging (299, 288) into a new token 676
# merging (503, 156) into a new token 677
# merging (326, 174) into a new token 678
# merging (272, 378) into a new token 679
# merging (158, 429) into a new token 680
# merging (349, 305) into a new token 681
# merging (135, 323) into a new token 682
# merging (306, 354) into a new token 683
# merging (579, 358) into a new token 684
# merging (522, 292) into a new token 685
# merging (290, 297) into a new token 686
# merging (308, 423) into a new token 687
# merging (158, 307) into a new token 688
# merging (283, 183) into a new token 689
# merging (358, 287) into a new token 690
# merging (168, 488) into a new token 691
# merging (317, 323) into a new token 692
# merging (260, 154) into a new token 693
# merging (275, 346) into a new token 694
# merging (302, 438) into a new token 695
# merging (347, 355) into a new token 696
# merging (269, 329) into a new token 697
# merging (338, 284) into a new token 698
# merging (317, 300) into a new token 699
# merging (304, 303) into a new token 700
# merging (295, 298) into a new token 701
# merging (331, 174) into a new token 702
# merging (306, 321) into a new token 703
# merging (296, 463) into a new token 704
# merging (294, 635) into a new token 705
# merging (314, 174) into a new token 706
# merging (291, 277) into a new token 707
# merging (319, 272) into a new token 708
# merging (310, 303) into a new token 709
# merging (362, 456) into a new token 710
# merging (283, 184) into a new token 711
# merging (262, 329) into a new token 712
# merging (475, 337) into a new token 713
# merging (267, 260) into a new token 714
# merging (287, 164) into a new token 715
# merging (476, 292) into a new token 716
# merging (407, 282) into a new token 717
# merging (342, 379) into a new token 718
# merging (263, 140) into a new token 719
# merging (268, 182) into a new token 720
# merging (268, 159) into a new token 721
# merging (262, 183) into a new token 722
# merging (681, 298) into a new token 723
# merging (134, 627) into a new token 724
# merging (299, 403) into a new token 725
# merging (418, 275) into a new token 726
# merging (316, 297) into a new token 727
# merging (306, 410) into a new token 728
# merging (532, 561) into a new token 729
# merging (305, 491) into a new token 730
# merging (268, 395) into a new token 731
# merging (304, 571) into a new token 732
# merging (308, 282) into a new token 733
# merging (178, 421) into a new token 734
# merging (135, 277) into a new token 735
# merging (296, 273) into a new token 736
# merging (350, 278) into a new token 737
# merging (184, 271) into a new token 738
# merging (260, 133) into a new token 739
# merging (322, 415) into a new token 740
# merging (328, 369) into a new token 741
# merging (282, 314) into a new token 742
# merging (143, 360) into a new token 743
# merging (287, 175) into a new token 744
# merging (659, 555) into a new token 745
# merging (434, 573) into a new token 746
# merging (569, 300) into a new token 747
# merging (405, 278) into a new token 748
# merging (271, 279) into a new token 749
# merging (297, 453) into a new token 750
# merging (290, 360) into a new token 751
# merging (175, 402) into a new token 752
# merging (256, 165) into a new token 753
# merging (471, 284) into a new token 754
# merging (300, 316) into a new token 755
# merging (347, 324) into a new token 756
# merging (260, 177) into a new token 757
# merging (326, 182) into a new token 758
# merging (260, 411) into a new token 759
# merging (299, 433) into a new token 760
# merging (310, 278) into a new token 761
# merging (147, 726) into a new token 762
# merging (290, 308) into a new token 763
# merging (394, 178) into a new token 764
# merging (397, 288) into a new token 765
# merging (277, 286) into a new token 766
# merging (283, 151) into a new token 767
# merging (332, 339) into a new token 768
# merging (295, 311) into a new token 769
# merging (565, 279) into a new token 770
# merging (376, 417) into a new token 771
# merging (316, 298) into a new token 772
# merging (172, 262) into a new token 773
# merging (260, 135) into a new token 774
# merging (291, 314) into a new token 775
# merging (465, 379) into a new token 776
# merging (470, 167) into a new token 777
# merging (273, 151) into a new token 778
# merging (457, 341) into a new token 779
# merging (297, 324) into a new token 780
# merging (261, 344) into a new token 781
# merging (326, 181) into a new token 782
# merging (256, 150) into a new token 783
# merging (268, 341) into a new token 784
# merging (464, 275) into a new token 785
# merging (591, 340) into a new token 786
# merging (137, 311) into a new token 787
# merging (259, 149) into a new token 788
# merging (286, 142) into a new token 789
# merging (405, 288) into a new token 790
# merging (471, 496) into a new token 791
# merging (260, 142) into a new token 792
# merging (164, 612) into a new token 793
# merging (305, 296) into a new token 794
# merging (287, 178) into a new token 795
# merging (156, 271) into a new token 796
# merging (295, 272) into a new token 797
# merging (287, 184) into a new token 798
# merging (286, 134) into a new token 799
# merging (286, 133) into a new token 800
# merging (283, 174) into a new token 801
# merging (260, 172) into a new token 802
# merging (290, 647) into a new token 803
# merging (291, 288) into a new token 804
# merging (164, 319) into a new token 805
# merging (154, 271) into a new token 806
# merging (426, 323) into a new token 807
# merging (262, 161) into a new token 808
# merging (166, 456) into a new token 809
# merging (305, 285) into a new token 810
# merging (277, 273) into a new token 811
# merging (340, 272) into a new token 812
# merging (295, 285) into a new token 813
# merging (262, 680) into a new token 814
# merging (286, 172) into a new token 815
# merging (308, 314) into a new token 816
# merging (262, 167) into a new token 817
# merging (268, 151) into a new token 818
# merging (326, 361) into a new token 819
# merging (283, 161) into a new token 820
# merging (326, 318) into a new token 821
# merging (149, 352) into a new token 822
# merging (401, 538) into a new token 823
# merging (273, 171) into a new token 824
# merging (268, 156) into a new token 825
# merging (277, 447) into a new token 826
# merging (260, 134) into a new token 827
# merging (182, 557) into a new token 828
# merging (826, 275) into a new token 829
# merging (705, 291) into a new token 830
# merging (268, 180) into a new token 831
# merging (425, 334) into a new token 832
# merging (606, 340) into a new token 833
# merging (666, 185) into a new token 834
# merging (32, 279) into a new token 835
# merging (302, 274) into a new token 836
# merging (424, 175) into a new token 837
# merging (567, 701) into a new token 838
# merging (479, 302) into a new token 839
# merging (300, 586) into a new token 840
# merging (312, 417) into a new token 841
# merging (156, 295) into a new token 842
# merging (184, 663) into a new token 843
# merging (462, 389) into a new token 844
# merging (844, 178) into a new token 845
# merging (309, 149) into a new token 846
# merging (338, 324) into a new token 847
# merging (273, 331) into a new token 848
# merging (699, 595) into a new token 849
# merging (651, 359) into a new token 850
# merging (356, 295) into a new token 851
# merging (365, 314) into a new token 852
# merging (171, 576) into a new token 853
# merging (311, 294) into a new token 854
# merging (282, 533) into a new token 855
# merging (345, 180) into a new token 856
# merging (260, 178) into a new token 857
# merging (285, 301) into a new token 858
# merging (327, 292) into a new token 859
# merging (273, 177) into a new token 860
# merging (297, 323) into a new token 861
# merging (137, 285) into a new token 862
# merging (276, 178) into a new token 863
# merging (166, 582) into a new token 864
# merging (287, 163) into a new token 865
# merging (304, 306) into a new token 866
# merging (352, 422) into a new token 867
# merging (317, 305) into a new token 868
# merging (260, 331) into a new token 869
# merging (349, 360) into a new token 870
# merging (177, 732) into a new token 871
# merging (178, 849) into a new token 872
# merging (298, 285) into a new token 873
# merging (400, 309) into a new token 874
# merging (290, 300) into a new token 875
# merging (262, 179) into a new token 876
# merging (611, 791) into a new token 877
# merging (316, 414) into a new token 878
# merging (271, 275) into a new token 879
# merging (316, 319) into a new token 880
# merging (290, 277) into a new token 881
# merging (170, 347) into a new token 882
# merging (297, 291) into a new token 883
# merging (172, 294) into a new token 884
# merging (283, 280) into a new token 885
# merging (710, 277) into a new token 886
# merging (174, 271) into a new token 887
# merging (259, 156) into a new token 888
# merging (374, 159) into a new token 889
# merging (275, 304) into a new token 890
# merging (334, 184) into a new token 891
# merging (181, 326) into a new token 892
# merging (273, 356) into a new token 893
# merging (167, 308) into a new token 894
# merging (268, 183) into a new token 895
# merging (601, 634) into a new token 896
# merging (534, 727) into a new token 897
# merging (372, 285) into a new token 898
# merging (273, 166) into a new token 899
# merging (402, 275) into a new token 900
# merging (269, 150) into a new token 901
# merging (303, 134) into a new token 902
# merging (271, 517) into a new token 903
# merging (182, 277) into a new token 904
# merging (273, 154) into a new token 905
# merging (369, 184) into a new token 906
# merging (167, 272) into a new token 907
# merging (260, 151) into a new token 908
# merging (747, 310) into a new token 909
# merging (279, 149) into a new token 910
# merging (332, 277) into a new token 911
# merging (276, 184) into a new token 912
# merging (260, 356) into a new token 913
# merging (355, 529) into a new token 914
# merging (343, 149) into a new token 915
# merging (174, 305) into a new token 916
# merging (265, 325) into a new token 917
# merging (146, 323) into a new token 918
# merging (272, 346) into a new token 919
# merging (159, 271) into a new token 920
# merging (174, 692) into a new token 921
# merging (259, 331) into a new token 922
# merging (283, 181) into a new token 923
# merging (257, 281) into a new token 924
# merging (287, 179) into a new token 925
# merging (133, 277) into a new token 926
# merging (262, 607) into a new token 927
# merging (286, 135) into a new token 928
# merging (347, 353) into a new token 929
# merging (316, 272) into a new token 930
# merging (303, 164) into a new token 931
# merging (286, 164) into a new token 932
# merging (371, 149) into a new token 933
# merging (745, 850) into a new token 934
# merging (638, 312) into a new token 935
# merging (339, 174) into a new token 936
# merging (495, 425) into a new token 937
# merging (259, 161) into a new token 938
# merging (342, 310) into a new token 939
# merging (318, 368) into a new token 940
# merging (262, 153) into a new token 941
# merging (301, 306) into a new token 942
# merging (470, 156) into a new token 943
# merging (335, 393) into a new token 944
# merging (181, 282) into a new token 945
# merging (450, 184) into a new token 946
# merging (372, 324) into a new token 947
# merging (581, 621) into a new token 948
# merging (394, 175) into a new token 949
# merging (311, 554) into a new token 950
# merging (269, 161) into a new token 951
# merging (531, 363) into a new token 952
# merging (277, 301) into a new token 953
# merging (559, 365) into a new token 954
# merging (262, 180) into a new token 955
# merging (480, 277) into a new token 956
# merging (291, 433) into a new token 957
# merging (319, 355) into a new token 958
# merging (461, 658) into a new token 959
# merging (182, 294) into a new token 960
# merging (298, 421) into a new token 961
# merging (542, 395) into a new token 962
# merging (665, 461) into a new token 963
# merging (273, 411) into a new token 964
# merging (295, 421) into a new token 965
# merging (664, 958) into a new token 966
# merging (277, 312) into a new token 967
# merging (272, 350) into a new token 968
# merging (262, 170) into a new token 969
# merging (287, 174) into a new token 970
# merging (321, 351) into a new token 971
# merging (271, 325) into a new token 972
# merging (181, 723) into a new token 973
# merging (404, 409) into a new token 974
# merging (135, 297) into a new token 975
# merging (345, 150) into a new token 976
# merging (394, 168) into a new token 977
# merging (276, 181) into a new token 978
# merging (297, 334) into a new token 979
# merging (314, 168) into a new token 980
# merging (374, 176) into a new token 981
# merging (339, 149) into a new token 982
# merging (377, 275) into a new token 983
# merging (290, 287) into a new token 984
# merging (449, 388) into a new token 985
# merging (339, 170) into a new token 986
# merging (309, 691) into a new token 987
# merging (283, 170) into a new token 988
# merging (504, 838) into a new token 989
# merging (386, 415) into a new token 990
# merging (729, 733) into a new token 991
# merging (300, 278) into a new token 992
# merging (167, 275) into a new token 993
# merging (260, 171) into a new token 994
# merging (176, 462) into a new token 995
# merging (286, 674) into a new token 996
# merging (754, 341) into a new token 997
# merging (268, 167) into a new token 998
# merging (303, 133) into a new token 999
# merging (149, 275) into a new token 1000
# merging (296, 274) into a new token 1001
# merging (713, 353) into a new token 1002
# merging (262, 400) into a new token 1003
# merging (184, 418) into a new token 1004
# merging (319, 720) into a new token 1005
# merging (319, 498) into a new token 1006
# merging (273, 136) into a new token 1007
# merging (440, 657) into a new token 1008
# merging (304, 284) into a new token 1009
# merging (389, 161) into a new token 1010
# merging (327, 324) into a new token 1011
# merging (356, 291) into a new token 1012
# merging (296, 289) into a new token 1013
# merging (177, 877) into a new token 1014
# merging (776, 301) into a new token 1015
# merging (439, 368) into a new token 1016
# merging (290, 311) into a new token 1017
# merging (352, 323) into a new token 1018
# merging (272, 456) into a new token 1019
# merging (472, 300) into a new token 1020
# merging (462, 337) into a new token 1021
# merging (309, 174) into a new token 1022
# merging (323, 288) into a new token 1023
# merging (336, 728) into a new token 1024
# merging (319, 334) into a new token 1025
# merging (437, 786) into a new token 1026
# merging (285, 288) into a new token 1027
# merging (457, 161) into a new token 1028
# merging (302, 328) into a new token 1029
# merging (272, 328) into a new token 1030
# merging (283, 168) into a new token 1031
# merging (369, 149) into a new token 1032
# merging (297, 272) into a new token 1033
# merging (513, 274) into a new token 1034
# merging (295, 297) into a new token 1035
# merging (758, 272) into a new token 1036
# merging (534, 602) into a new token 1037
# merging (762, 996) into a new token 1038
# merging (174, 845) into a new token 1039
# merging (468, 175) into a new token 1040
# merging (927, 1017) into a new token 1041
# merging (427, 274) into a new token 1042
# merging (755, 597) into a new token 1043
# merging (334, 149) into a new token 1044
# merging (177, 285) into a new token 1045
# merging (499, 353) into a new token 1046
# merging (299, 282) into a new token 1047
# merging (302, 432) into a new token 1048
# merging (393, 174) into a new token 1049
# merging (271, 305) into a new token 1050
# merging (158, 529) into a new token 1051
# merging (349, 308) into a new token 1052
# merging (295, 520) into a new token 1053
# merging (545, 603) into a new token 1054
# merging (629, 840) into a new token 1055
# merging (321, 338) into a new token 1056
# merging (309, 168) into a new token 1057
# merging (268, 688) into a new token 1058
# merging (889, 343) into a new token 1059
# merging (301, 303) into a new token 1060
# merging (480, 359) into a new token 1061
# merging (873, 481) into a new token 1062
# merging (273, 159) into a new token 1063
# merging (271, 399) into a new token 1064
# merging (32, 325) into a new token 1065
# merging (144, 950) into a new token 1066
# merging (546, 643) into a new token 1067
# merging (502, 578) into a new token 1068
# merging (356, 366) into a new token 1069
# merging (314, 184) into a new token 1070
# merging (10, 275) into a new token 1071
# merging (32, 287) into a new token 1072
# merging (298, 366) into a new token 1073
# merging (408, 417) into a new token 1074
# merging (351, 439) into a new token 1075
# merging (260, 156) into a new token 1076
# merging (308, 817) into a new token 1077
# merging (427, 284) into a new token 1078
# merging (286, 177) into a new token 1079
# merging (282, 769) into a new token 1080
# merging (158, 369) into a new token 1081
# merging (283, 177) into a new token 1082
# merging (675, 697) into a new token 1083
# merging (262, 151) into a new token 1084
# merging (398, 275) into a new token 1085
# merging (387, 271) into a new token 1086
# merging (286, 178) into a new token 1087
# merging (326, 156) into a new token 1088
# merging (376, 346) into a new token 1089
# merging (783, 638) into a new token 1090
# merging (133, 435) into a new token 1091
# merging (310, 496) into a new token 1092
# merging (349, 300) into a new token 1093
# merging (181, 968) into a new token 1094
# merging (296, 278) into a new token 1095
# merging (309, 170) into a new token 1096
# merging (273, 147) into a new token 1097
# merging (345, 161) into a new token 1098
# merging (181, 290) into a new token 1099
# merging (273, 156) into a new token 1100
# merging (430, 312) into a new token 1101
# merging (274, 184) into a new token 1102
# merging (301, 317) into a new token 1103
# merging (134, 777) into a new token 1104
# merging (287, 181) into a new token 1105
# merging (344, 168) into a new token 1106
# merging (256, 152) into a new token 1107
# merging (292, 294) into a new token 1108
# merging (625, 312) into a new token 1109
# merging (295, 476) into a new token 1110
# merging (712, 302) into a new token 1111
# merging (600, 425) into a new token 1112
# merging (796, 311) into a new token 1113
# merging (161, 294) into a new token 1114
# merging (358, 279) into a new token 1115
# merging (491, 452) into a new token 1116
# merging (702, 310) into a new token 1117
# merging (468, 176) into a new token 1118
# merging (420, 460) into a new token 1119
# merging (1119, 951) into a new token 1120
# merging (470, 404) into a new token 1121
# merging (338, 1035) into a new token 1122
# merging (385, 349) into a new token 1123
# merging (300, 447) into a new token 1124
# merging (995, 350) into a new token 1125
# merging (295, 360) into a new token 1126
# merging (343, 184) into a new token 1127
# merging (301, 277) into a new token 1128
# merging (142, 285) into a new token 1129
# merging (271, 467) into a new token 1130
# merging (142, 299) into a new token 1131
# merging (347, 298) into a new token 1132
# merging (295, 277) into a new token 1133
# merging (342, 385) into a new token 1134
# merging (262, 166) into a new token 1135
# merging (262, 185) into a new token 1136
# merging (390, 168) into a new token 1137
# merging (278, 278) into a new token 1138
# merging (1048, 594) into a new token 1139
# merging (874, 588) into a new token 1140
# merging (290, 285) into a new token 1141
# merging (978, 779) into a new token 1142
# merging (306, 310) into a new token 1143
# merging (756, 288) into a new token 1144
# merging (312, 266) into a new token 1145
# merging (277, 474) into a new token 1146
# merging (308, 275) into a new token 1147
# merging (286, 151) into a new token 1148
# merging (469, 395) into a new token 1149
# merging (1109, 1059) into a new token 1150
# merging (575, 961) into a new token 1151
# merging (481, 274) into a new token 1152
# merging (1116, 623) into a new token 1153
# merging (401, 669) into a new token 1154
# merging (540, 1067) into a new token 1155
# merging (166, 1080) into a new token 1156
# merging (540, 271) into a new token 1157
# merging (363, 174) into a new token 1158
# merging (277, 294) into a new token 1159
# merging (321, 260) into a new token 1160
# merging (181, 593) into a new token 1161
# merging (328, 314) into a new token 1162
# merging (181, 301) into a new token 1163
# merging (324, 312) into a new token 1164
# merging (328, 310) into a new token 1165
# merging (411, 489) into a new token 1166
# merging (297, 422) into a new token 1167
# merging (351, 335) into a new token 1168
# merging (842, 308) into a new token 1169
# merging (168, 338) into a new token 1170
# merging (317, 298) into a new token 1171
# merging (344, 176) into a new token 1172
# merging (287, 177) into a new token 1173
# merging (897, 830) into a new token 1174
# merging (268, 173) into a new token 1175
# merging (862, 807) into a new token 1176
# merging (513, 417) into a new token 1177
# merging (355, 594) into a new token 1178
# merging (449, 761) into a new token 1179
# merging (296, 657) into a new token 1180
# merging (773, 1113) into a new token 1181
# merging (520, 346) into a new token 1182
# merging (458, 586) into a new token 1183
# merging (356, 1090) into a new token 1184
# merging (363, 149) into a new token 1185
# merging (632, 274) into a new token 1186
# merging (756, 832) into a new token 1187
# merging (1078, 660) into a new token 1188
# merging (287, 151) into a new token 1189
# merging (805, 530) into a new token 1190
# merging (306, 413) into a new token 1191
# merging (406, 388) into a new token 1192
# merging (377, 412) into a new token 1193
# merging (504, 785) into a new token 1194
# merging (305, 309) into a new token 1195
# merging (677, 301) into a new token 1196
# merging (317, 279) into a new token 1197
# merging (698, 174) into a new token 1198
# merging (625, 511) into a new token 1199
# merging (282, 553) into a new token 1200
# merging (384, 770) into a new token 1201
# merging (299, 765) into a new token 1202
# merging (389, 183) into a new token 1203
# merging (633, 823) into a new token 1204
# merging (715, 278) into a new token 1205
# merging (371, 184) into a new token 1206
# merging (426, 325) into a new token 1207
# merging (154, 1123) into a new token 1208
# merging (291, 423) into a new token 1209
# merging (314, 170) into a new token 1210
# merging (342, 637) into a new token 1211
# merging (291, 354) into a new token 1212
# merging (265, 523) into a new token 1213
# merging (144, 597) into a new token 1214
# merging (903, 309) into a new token 1215
# merging (268, 329) into a new token 1216
# merging (371, 174) into a new token 1217
# merging (464, 272) into a new token 1218
# merging (626, 654) into a new token 1219
# merging (392, 888) into a new token 1220
# merging (310, 346) into a new token 1221
# merging (178, 1187) into a new token 1222
# merging (286, 538) into a new token 1223
# merging (275, 391) into a new token 1224
# merging (584, 310) into a new token 1225
# merging (181, 662) into a new token 1226
# merging (303, 135) into a new token 1227
# merging (556, 352) into a new token 1228
# merging (475, 302) into a new token 1229
# merging (432, 997) into a new token 1230
# merging (343, 178) into a new token 1231
# merging (866, 385) into a new token 1232
# merging (606, 324) into a new token 1233
# merging (505, 558) into a new token 1234
# merging (642, 939) into a new token 1235
# merging (261, 390) into a new token 1236
# merging (273, 161) into a new token 1237
# merging (298, 296) into a new token 1238
# merging (269, 851) into a new token 1239
# merging (290, 260) into a new token 1240
# merging (471, 661) into a new token 1241
# merging (154, 1015) into a new token 1242
# merging (298, 346) into a new token 1243
# merging (648, 695) into a new token 1244
# merging (181, 577) into a new token 1245
# merging (348, 149) into a new token 1246
# merging (579, 466) into a new token 1247
# merging (151, 709) into a new token 1248
# merging (501, 541) into a new token 1249
# merging (347, 304) into a new token 1250
# merging (276, 164) into a new token 1251
# merging (170, 317) into a new token 1252
# merging (819, 334) into a new token 1253
# merging (409, 184) into a new token 1254
# merging (372, 446) into a new token 1255
# merging (268, 185) into a new token 1256
# merging (1145, 1146) into a new token 1257
# merging (274, 149) into a new token 1258
# merging (272, 288) into a new token 1259
# merging (509, 293) into a new token 1260
# merging (259, 155) into a new token 1261
# merging (1150, 573) into a new token 1262
# merging (173, 818) into a new token 1263
# merging (272, 303) into a new token 1264
# merging (273, 650) into a new token 1265
# merging (449, 301) into a new token 1266
# merging (355, 615) into a new token 1267
# merging (273, 137) into a new token 1268
# merging (377, 488) into a new token 1269
# merging (372, 483) into a new token 1270
# merging (837, 518) into a new token 1271
# merging (143, 854) into a new token 1272
# merging (312, 661) into a new token 1273
# merging (273, 185) into a new token 1274
# merging (343, 133) into a new token 1275
# merging (506, 697) into a new token 1276
# merging (386, 325) into a new token 1277
# merging (271, 518) into a new token 1278
# merging (171, 294) into a new token 1279
# merging (168, 479) into a new token 1280
# merging (322, 319) into a new token 1281
# merging (309, 164) into a new token 1282
# merging (275, 335) into a new token 1283
# merging (295, 519) into a new token 1284
# merging (374, 184) into a new token 1285
# merging (349, 319) into a new token 1286
# merging (480, 339) into a new token 1287
# merging (481, 496) into a new token 1288
# merging (164, 278) into a new token 1289
# merging (497, 568) into a new token 1290
# merging (424, 149) into a new token 1291
# merging (262, 281) into a new token 1292
# merging (298, 567) into a new token 1293
# merging (960, 306) into a new token 1294
# merging (372, 260) into a new token 1295
# merging (142, 467) into a new token 1296
# merging (505, 312) into a new token 1297
# merging (678, 381) into a new token 1298
# merging (279, 184) into a new token 1299
# merging (718, 615) into a new token 1300
# merging (411, 303) into a new token 1301
# merging (286, 331) into a new token 1302
# merging (10, 943) into a new token 1303
# merging (268, 172) into a new token 1304
# merging (390, 176) into a new token 1305
# merging (260, 166) into a new token 1306
# merging (291, 527) into a new token 1307
# merging (308, 377) into a new token 1308
# merging (740, 310) into a new token 1309
# merging (345, 607) into a new token 1310
# merging (689, 301) into a new token 1311
# merging (154, 282) into a new token 1312
# merging (431, 620) into a new token 1313
# merging (356, 1225) into a new token 1314
# merging (462, 772) into a new token 1315
# merging (1250, 1288) into a new token 1316
# merging (626, 301) into a new token 1317
# merging (624, 965) into a new token 1318
# merging (611, 867) into a new token 1319
# merging (793, 553) into a new token 1320
# merging (285, 423) into a new token 1321
# merging (383, 352) into a new token 1322
# merging (401, 871) into a new token 1323
# merging (319, 505) into a new token 1324
# merging (746, 588) into a new token 1325
# merging (269, 183) into a new token 1326
# merging (554, 494) into a new token 1327
# merging (133, 750) into a new token 1328
# merging (330, 274) into a new token 1329
# merging (356, 308) into a new token 1330
# merging (283, 361) into a new token 1331
# merging (176, 475) into a new token 1332
# merging (273, 667) into a new token 1333
# merging (382, 445) into a new token 1334
# merging (183, 365) into a new token 1335
# merging (468, 168) into a new token 1336
# merging (454, 397) into a new token 1337
# merging (291, 550) into a new token 1338
# merging (290, 305) into a new token 1339
# merging (387, 322) into a new token 1340
# merging (394, 149) into a new token 1341
# merging (843, 343) into a new token 1342
# merging (146, 445) into a new token 1343
# merging (170, 357) into a new token 1344
# merging (718, 302) into a new token 1345
# merging (181, 1073) into a new token 1346
# merging (675, 339) into a new token 1347
# merging (622, 1261) into a new token 1348
# merging (347, 418) into a new token 1349
# merging (331, 834) into a new token 1350
# merging (314, 135) into a new token 1351
# merging (460, 300) into a new token 1352
# merging (457, 940) into a new token 1353
# merging (290, 302) into a new token 1354
# merging (321, 708) into a new token 1355
# merging (133, 306) into a new token 1356
# merging (284, 361) into a new token 1357
# merging (285, 305) into a new token 1358
# merging (182, 425) into a new token 1359
# merging (828, 1179) into a new token 1360
# merging (316, 324) into a new token 1361
# merging (347, 439) into a new token 1362
# merging (1311, 1049) into a new token 1363
# merging (976, 298) into a new token 1364
# merging (268, 559) into a new token 1365
# merging (300, 301) into a new token 1366
# merging (424, 178) into a new token 1367
# merging (259, 171) into a new token 1368
# merging (269, 166) into a new token 1369
# merging (297, 371) into a new token 1370
# merging (287, 149) into a new token 1371
# merging (743, 816) into a new token 1372
# merging (296, 636) into a new token 1373
# merging (273, 628) into a new token 1374
# merging (464, 334) into a new token 1375
# merging (384, 1197) into a new token 1376
# merging (1345, 340) into a new token 1377
# merging (472, 303) into a new token 1378
# merging (297, 299) into a new token 1379
# merging (624, 351) into a new token 1380
# merging (184, 704) into a new token 1381
# merging (476, 301) into a new token 1382
# merging (273, 175) into a new token 1383
# merging (1229, 614) into a new token 1384
# merging (260, 137) into a new token 1385
# merging (261, 523) into a new token 1386
# merging (485, 312) into a new token 1387
# merging (298, 517) into a new token 1388
# merging (406, 271) into a new token 1389
# merging (283, 130) into a new token 1390
# merging (1114, 808) into a new token 1391
# merging (428, 847) into a new token 1392
# merging (288, 170) into a new token 1393
# merging (271, 360) into a new token 1394
# merging (262, 163) into a new token 1395
# merging (283, 180) into a new token 1396
# merging (271, 298) into a new token 1397
# merging (752, 518) into a new token 1398
# merging (269, 184) into a new token 1399
# merging (398, 412) into a new token 1400
# merging (172, 271) into a new token 1401
# merging (262, 144) into a new token 1402
# merging (177, 1316) into a new token 1403
# merging (469, 180) into a new token 1404
# merging (268, 419) into a new token 1405
# merging (1026, 371) into a new token 1406
# merging (316, 279) into a new token 1407
# merging (151, 1290) into a new token 1408
# merging (142, 655) into a new token 1409
# merging (306, 300) into a new token 1410
# merging (272, 266) into a new token 1411
# merging (1045, 393) into a new token 1412
# merging (542, 1391) into a new token 1413
# merging (164, 1018) into a new token 1414
# merging (351, 861) into a new token 1415
# merging (515, 295) into a new token 1416
# merging (181, 296) into a new token 1417
# merging (334, 174) into a new token 1418
# merging (260, 159) into a new token 1419
# merging (338, 333) into a new token 1420
# merging (892, 809) into a new token 1421
# merging (648, 1139) into a new token 1422
# merging (185, 568) into a new token 1423
# merging (10, 260) into a new token 1424
# merging (1363, 1284) into a new token 1425
# merging (514, 275) into a new token 1426
# merging (149, 839) into a new token 1427
# merging (295, 324) into a new token 1428
# merging (291, 413) into a new token 1429
# merging (1069, 1245) into a new token 1430
# merging (269, 173) into a new token 1431
# merging (286, 993) into a new token 1432
# merging (286, 159) into a new token 1433
# merging (322, 311) into a new token 1434
# merging (389, 177) into a new token 1435
# merging (258, 596) into a new token 1436
# merging (1055, 299) into a new token 1437
# merging (467, 260) into a new token 1438
# merging (305, 408) into a new token 1439
# merging (277, 296) into a new token 1440
# merging (288, 184) into a new token 1441
# ...
# merging (275, 288) into a new token 4617
# merging (677, 2964) into a new token 4618
# merging (1634, 483) into a new token 4619
# merging (303, 2095) into a new token 4620
# merging (630, 886) into a new token 4621
# merging (618, 272) into a new token 4622
# merging (277, 406) into a new token 4623
# merging (295, 647) into a new token 4624
# merging (3204, 513) into a new token 4625
# merging (464, 580) into a new token 4626
# merging (352, 308) into a new token 4627
# merging (328, 2968) into a new token 4628
# merging (272, 291) into a new token 4629
# merging (352, 324) into a new token 4630
# merging (260, 559) into a new token 4631
# merging (585, 149) into a new token 4632
# merging (444, 640) into a new token 4633
# merging (1132, 3460) into a new token 4634
# merging (4634, 4142) into a new token 4635
# merging (396, 272) into a new token 4636
# merging (342, 381) into a new token 4637
# merging (449, 497) into a new token 4638
# merging (319, 761) into a new token 4639
# merging (381, 1013) into a new token 4640
# merging (1105, 715) into a new token 4641
# merging (4641, 4059) into a new token 4642
# merging (1856, 1179) into a new token 4643
# merging (1103, 415) into a new token 4644
# merging (1729, 949) into a new token 4645
# merging (320, 428) into a new token 4646
# merging (3463, 174) into a new token 4647
# merging (510, 172) into a new token 4648
# merging (267, 1086) into a new token 4649
# merging (135, 2711) into a new token 4650
# merging (159, 4162) into a new token 4651
# merging (459, 355) into a new token 4652
# merging (537, 389) into a new token 4653
# merging (2282, 1966) into a new token 4654
# merging (335, 1018) into a new token 4655
# merging (298, 291) into a new token 4656
# merging (181, 1756) into a new token 4657
# merging (3224, 2495) into a new token 4658
# merging (445, 291) into a new token 4659
# merging (377, 277) into a new token 4660
# merging (804, 1918) into a new token 4661
# merging (2379, 3666) into a new token 4662
# merging (724, 303) into a new token 4663
# merging (1914, 372) into a new token 4664
# merging (1540, 2475) into a new token 4665
# merging (1414, 2993) into a new token 4666
# merging (486, 2207) into a new token 4667
# merging (2292, 570) into a new token 4668
# merging (133, 322) into a new token 4669
# merging (547, 300) into a new token 4670
# merging (3792, 2794) into a new token 4671
# merging (277, 380) into a new token 4672
# merging (870, 309) into a new token 4673
# merging (785, 355) into a new token 4674
# merging (171, 337) into a new token 4675
# merging (629, 2195) into a new token 4676
# merging (1638, 2501) into a new token 4677
# merging (2816, 1703) into a new token 4678
# merging (2773, 310) into a new token 4679
# merging (137, 306) into a new token 4680
# merging (1132, 555) into a new token 4681
# merging (1305, 390) into a new token 4682
# merging (265, 3005) into a new token 4683
# merging (514, 305) into a new token 4684
# merging (297, 768) into a new token 4685
# merging (2115, 3233) into a new token 4686
# merging (738, 1554) into a new token 4687
# merging (4189, 136) into a new token 4688
# merging (4688, 360) into a new token 4689
# merging (443, 1216) into a new token 4690
# merging (146, 311) into a new token 4691
# merging (3236, 399) into a new token 4692
# merging (332, 2642) into a new token 4693
# merging (396, 418) into a new token 4694
# merging (271, 272) into a new token 4695
# merging (712, 1259) into a new token 4696
# merging (1941, 291) into a new token 4697
# merging (1797, 1124) into a new token 4698
# merging (3448, 4202) into a new token 4699
# merging (151, 564) into a new token 4700
# merging (418, 988) into a new token 4701
# merging (4701, 2355) into a new token 4702
# merging (2780, 1286) into a new token 4703
# merging (2213, 491) into a new token 4704
# merging (278, 294) into a new token 4705
# merging (822, 432) into a new token 4706
# merging (678, 841) into a new token 4707
# merging (1867, 339) into a new token 4708
# merging (527, 149) into a new token 4709
# merging (2645, 790) into a new token 4710
# merging (2303, 974) into a new token 4711
# merging (133, 323) into a new token 4712
# merging (327, 1869) into a new token 4713
# merging (1160, 963) into a new token 4714
# merging (2110, 303) into a new token 4715
# merging (487, 1153) into a new token 4716
# merging (2286, 439) into a new token 4717
# merging (332, 387) into a new token 4718
# merging (2121, 943) into a new token 4719
# merging (493, 1234) into a new token 4720
# merging (640, 551) into a new token 4721
# merging (3517, 594) into a new token 4722
# merging (260, 2277) into a new token 4723
# merging (1410, 1042) into a new token 4724
# merging (1566, 306) into a new token 4725
# merging (1635, 2830) into a new token 4726
# merging (174, 820) into a new token 4727
# merging (371, 181) into a new token 4728
# merging (881, 1535) into a new token 4729
# merging (286, 2125) into a new token 4730
# merging (743, 3823) into a new token 4731
# merging (469, 172) into a new token 4732
# merging (291, 2331) into a new token 4733
# merging (449, 285) into a new token 4734
# merging (796, 494) into a new token 4735
# merging (4735, 670) into a new token 4736
# merging (156, 1912) into a new token 4737
# merging (299, 275) into a new token 4738
# merging (1095, 695) into a new token 4739
# merging (685, 466) into a new token 4740
# merging (1396, 447) into a new token 4741
# merging (354, 172) into a new token 4742
# merging (288, 156) into a new token 4743
# merging (2972, 303) into a new token 4744
# merging (394, 341) into a new token 4745
# merging (3266, 428) into a new token 4746
# merging (4746, 870) into a new token 4747
# merging (3835, 397) into a new token 4748
# merging (181, 681) into a new token 4749
# merging (1154, 451) into a new token 4750
# merging (875, 275) into a new token 4751
# merging (754, 361) into a new token 4752
# merging (4752, 305) into a new token 4753
# merging (2840, 4243) into a new token 4754
# merging (525, 339) into a new token 4755
# merging (2283, 1264) into a new token 4756
# merging (3274, 381) into a new token 4757
# merging (524, 525) into a new token 4758
# merging (671, 2662) into a new token 4759
# merging (10, 470) into a new token 4760
# merging (475, 295) into a new token 4761
# merging (295, 679) into a new token 4762
# merging (1012, 308) into a new token 4763
# merging (3045, 142) into a new token 4764
# merging (755, 360) into a new token 4765
# merging (1176, 359) into a new token 4766
# merging (1111, 288) into a new token 4767
# merging (347, 299) into a new token 4768
# merging (285, 742) into a new token 4769
# merging (297, 306) into a new token 4770
# merging (166, 3850) into a new token 4771
# merging (304, 442) into a new token 4772
# merging (431, 1355) into a new token 4773
# merging (724, 2453) into a new token 4774
# merging (317, 308) into a new token 4775
# merging (2668, 2472) into a new token 4776
# merging (144, 399) into a new token 4777
# merging (304, 272) into a new token 4778
# merging (1409, 645) into a new token 4779
# merging (1696, 1461) into a new token 4780
# merging (3834, 3057) into a new token 4781
# merging (291, 1476) into a new token 4782
# merging (322, 1107) into a new token 4783
# merging (3867, 558) into a new token 4784
# merging (547, 418) into a new token 4785
# merging (349, 374) into a new token 4786
# merging (1247, 934) into a new token 4787
# merging (402, 637) into a new token 4788
# merging (983, 405) into a new token 4789
# merging (3869, 2654) into a new token 4790
# merging (1812, 741) into a new token 4791
# merging (564, 1794) into a new token 4792
# merging (407, 2036) into a new token 4793
# merging (151, 301) into a new token 4794
# merging (2518, 486) into a new token 4795
# merging (513, 309) into a new token 4796
# merging (4120, 3874) into a new token 4797
# merging (1047, 553) into a new token 4798
# merging (260, 608) into a new token 4799
# merging (454, 384) into a new token 4800
# merging (308, 1273) into a new token 4801
# merging (299, 368) into a new token 4802
# merging (4802, 134) into a new token 4803
# merging (4803, 4277) into a new token 4804
# merging (2642, 530) into a new token 4805
# merging (467, 308) into a new token 4806
# merging (373, 453) into a new token 4807
# merging (181, 580) into a new token 4808
# merging (604, 490) into a new token 4809
# merging (632, 423) into a new token 4810
# merging (2326, 451) into a new token 4811
# merging (380, 297) into a new token 4812
# merging (713, 1110) into a new token 4813
# merging (609, 303) into a new token 4814
# merging (260, 667) into a new token 4815
# merging (449, 402) into a new token 4816
# merging (4816, 353) into a new token 4817
# merging (1430, 343) into a new token 4818
# merging (352, 439) into a new token 4819
# merging (2185, 2328) into a new token 4820
# merging (805, 819) into a new token 4821
# merging (3304, 4281) into a new token 4822
# merging (800, 1911) into a new token 4823
# merging (4282, 2363) into a new token 4824
# merging (445, 285) into a new token 4825
# merging (1403, 1564) into a new token 4826
# merging (144, 398) into a new token 4827
# merging (1767, 420) into a new token 4828
# merging (285, 1001) into a new token 4829
# merging (986, 730) into a new token 4830
# merging (151, 3072) into a new token 4831
# merging (4831, 305) into a new token 4832
# merging (4832, 748) into a new token 4833
# merging (1748, 709) into a new token 4834
# merging (286, 147) into a new token 4835
# merging (608, 397) into a new token 4836
# merging (984, 182) into a new token 4837
# merging (326, 907) into a new token 4838
# merging (396, 671) into a new token 4839
# merging (3312, 1537) into a new token 4840
# merging (902, 777) into a new token 4841
# merging (3581, 1382) into a new token 4842
# merging (719, 363) into a new token 4843
# merging (1401, 1384) into a new token 4844
# merging (342, 685) into a new token 4845
# merging (1071, 462) into a new token 4846
# merging (3080, 1819) into a new token 4847
# merging (510, 168) into a new token 4848
# merging (345, 167) into a new token 4849
# merging (535, 383) into a new token 4850
# merging (610, 619) into a new token 4851
# merging (151, 522) into a new token 4852
# merging (2860, 2134) into a new token 4853
# merging (420, 924) into a new token 4854
# merging (4298, 4299) into a new token 4855
# merging (282, 972) into a new token 4856
# merging (457, 174) into a new token 4857
# merging (4857, 876) into a new token 4858
# merging (339, 2861) into a new token 4859
# merging (1752, 308) into a new token 4860
# merging (2135, 2150) into a new token 4861
# merging (1105, 798) into a new token 4862
# merging (949, 2271) into a new token 4863
# merging (385, 602) into a new token 4864
# merging (383, 875) into a new token 4865
# merging (171, 3083) into a new token 4866
# merging (3126, 3137) into a new token 4867
# merging (766, 552) into a new token 4868
# merging (459, 300) into a new token 4869
# merging (1425, 446) into a new token 4870
# merging (170, 299) into a new token 4871
# merging (2537, 2859) into a new token 4872
# merging (133, 2267) into a new token 4873
# merging (3552, 303) into a new token 4874
# merging (493, 1046) into a new token 4875
# merging (4875, 3905) into a new token 4876
# merging (394, 159) into a new token 4877
# merging (143, 819) into a new token 4878
# merging (174, 335) into a new token 4879
# merging (1339, 288) into a new token 4880
# merging (859, 1177) into a new token 4881
# merging (3046, 3597) into a new token 4882
# merging (1181, 510) into a new token 4883
# merging (1833, 3403) into a new token 4884
# merging (1826, 2249) into a new token 4885
# merging (303, 918) into a new token 4886
# merging (1268, 979) into a new token 4887
# merging (502, 1598) into a new token 4888
# merging (4888, 455) into a new token 4889
# merging (296, 2539) into a new token 4890
# merging (1065, 3599) into a new token 4891
# merging (465, 676) into a new token 4892
# merging (2709, 694) into a new token 4893
# merging (4327, 3917) into a new token 4894
# merging (1800, 4258) into a new token 4895
# merging (1537, 2137) into a new token 4896
# merging (3600, 4329) into a new token 4897
# merging (640, 1074) into a new token 4898
# merging (693, 2069) into a new token 4899
# merging (174, 418) into a new token 4900
# merging (142, 2046) into a new token 4901
# merging (380, 2684) into a new token 4902
# merging (367, 766) into a new token 4903
# merging (714, 2823) into a new token 4904
# merging (4332, 808) into a new token 4905
# merging (475, 298) into a new token 4906
# merging (4906, 614) into a new token 4907
# merging (3154, 174) into a new token 4908
# merging (4908, 445) into a new token 4909
# merging (1842, 2522) into a new token 4910
# merging (2087, 3333) into a new token 4911
# merging (334, 183) into a new token 4912
# merging (1721, 355) into a new token 4913
# merging (618, 493) into a new token 4914
# merging (379, 1402) into a new token 4915
# merging (670, 508) into a new token 4916
# merging (2016, 304) into a new token 4917
# merging (291, 1561) into a new token 4918
# merging (296, 456) into a new token 4919
# merging (4919, 1913) into a new token 4920
# merging (659, 602) into a new token 4921
# merging (577, 303) into a new token 4922
# merging (459, 2686) into a new token 4923
# merging (486, 1585) into a new token 4924
# merging (3089, 2687) into a new token 4925
# merging (2103, 451) into a new token 4926
# merging (3278, 1418) into a new token 4927
# merging (454, 302) into a new token 4928
# merging (142, 1573) into a new token 4929
# merging (422, 184) into a new token 4930
# merging (334, 172) into a new token 4931
# merging (1757, 368) into a new token 4932
# merging (306, 4347) into a new token 4933
# merging (324, 558) into a new token 4934
# merging (2588, 286) into a new token 4935
# merging (4935, 4349) into a new token 4936
# merging (669, 1034) into a new token 4937
# merging (796, 597) into a new token 4938
# merging (3016, 2064) into a new token 4939
# merging (1085, 838) into a new token 4940
# merging (365, 348) into a new token 4941
# merging (308, 801) into a new token 4942
# merging (532, 465) into a new token 4943
# merging (773, 151) into a new token 4944
# merging (3805, 640) into a new token 4945
# merging (3929, 409) into a new token 4946
# merging (171, 298) into a new token 4947
# merging (620, 679) into a new token 4948
# merging (898, 548) into a new token 4949
# merging (470, 181) into a new token 4950
# merging (1104, 1324) into a new token 4951
# merging (164, 1699) into a new token 4952
# merging (622, 890) into a new token 4953
# merging (3938, 3342) into a new token 4954
# merging (428, 282) into a new token 4955
# merging (369, 177) into a new token 4956
# merging (147, 3071) into a new token 4957
# merging (4957, 4365) into a new token 4958
# merging (295, 326) into a new token 4959
# merging (470, 974) into a new token 4960
# merging (168, 295) into a new token 4961
# merging (4231, 384) into a new token 4962
# merging (675, 982) into a new token 4963
# merging (1896, 413) into a new token 4964
# merging (317, 418) into a new token 4965
# merging (1356, 4313) into a new token 4966
# merging (321, 363) into a new token 4967
# merging (275, 291) into a new token 4968
# merging (2126, 343) into a new token 4969
# merging (803, 260) into a new token 4970
# merging (1959, 2415) into a new token 4971
# merging (2255, 3347) into a new token 4972
# merging (566, 2140) into a new token 4973
# merging (3948, 3348) into a new token 4974
# merging (593, 1483) into a new token 4975
# merging (430, 3099) into a new token 4976
# merging (167, 1031) into a new token 4977
# merging (2213, 483) into a new token 4978
# merging (297, 619) into a new token 4979
# merging (147, 399) into a new token 4980
# merging (271, 695) into a new token 4981
# merging (2551, 790) into a new token 4982
# merging (137, 1033) into a new token 4983
# merging (133, 3584) into a new token 4984
# merging (4369, 3951) into a new token 4985
# merging (273, 1378) into a new token 4986
# merging (2620, 4386) into a new token 4987
# merging (642, 308) into a new token 4988
# merging (500, 1393) into a new token 4989
# merging (675, 335) into a new token 4990
# merging (1192, 336) into a new token 4991
# merging (149, 1388) into a new token 4992
# merging (1360, 4387) into a new token 4993
# merging (430, 1235) into a new token 4994
# merging (2872, 1683) into a new token 4995
# merging (614, 1549) into a new token 4996
# merging (172, 525) into a new token 4997
# merging (1273, 351) into a new token 4998
# merging (630, 730) into a new token 4999

# %%
print("tokens length:", len(tokens))
print("ids length:", len(ids))
print(f"compression ratio: {len(tokens) / len(ids):.2f}X")
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# tokens length: 1043456
# ids length: 88500
# compression ratio: 11.79X

# %% [markdown]
# ## Decode

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
    vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  # given ids (list of integers), return Python string
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors="replace")
  return text

print(decode([350, 351]))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ിതിക

# %% [markdown]
# ## Encode

# %%
def encode(text):
  # given a string, return list of integers (the tokens)
  tokens = list(text.encode("utf-8"))
  while len(tokens) >= 2:
    stats = get_stats(tokens)
    pair = min(stats, key=lambda p: merges.get(p, float("inf")))
    if pair not in merges:
      break # nothing else can be merged
    idx = merges[pair]
    tokens = merge(tokens, pair, idx)
  return tokens

print(encode("ജോലിയില്‍ നിന്ന്"))
print(len(encode("ജോലിയില്‍ നിന്ന്")))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [515, 581, 510, 168, 488, 258]
# 6

# %%
print(decode([515, 581, 510, 168, 488, 258]))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# ജോലിയില്‍ നിന്ന്

# %% [markdown]
# ## Sentence piece

# %%
import sentencepiece as spm
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
# train a sentencepiece model on it
# the settings here are (best effort) those used for training Llama 2
import os

options = dict(
  # input spec
  input="malayalam.txt",
  input_format="text",
  # output spec
  model_prefix="tok_ml", # output filename prefix
  # algorithm spec
  # BPE alg
  model_type="bpe",
  vocab_size=5000,
  # normalization
  normalization_rule_name="identity", # ew, turn off normalization
  remove_extra_whitespaces=False,
  input_sentence_size=200000000, # max number of training sentences
  max_sentence_length=4192, # max number of bytes per sentence
  seed_sentencepiece_size=1000000,
  shuffle_input_sentence=True,
  # rare word treatment
  character_coverage=0.99995,
  byte_fallback=True,
  # merge rules
  split_digits=True,
  split_by_unicode_script=True,
  split_by_whitespace=True,
  split_by_number=True,
  max_sentencepiece_length=16,
  add_dummy_prefix=True,
  allow_whitespace_only_pieces=True,
  # special tokens
  unk_id=0, # the UNK token MUST exist
  bos_id=1, # the others are optional, set to -1 to turn off
  eos_id=2,
  pad_id=-1,
  # systems
  num_threads=os.cpu_count(), # use ~all system resources
)

spm.SentencePieceTrainer.train(**options)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
sp = spm.SentencePieceProcessor()
sp.load('tok_ml.model')
vocab = [[sp.id_to_piece(idx), idx] for idx in range(sp.get_piece_size())]
vocab[272:]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [['്ട', 272],
#  ['ത്ത', 273],
#  ['▁മ', 274],
#  ['്റ', 275],
#  ['ച്', 276],
#  ['ില്\u200d', 277],
#  ['▁ന', 278],
#  ['ും', 279],
#  ['പ്', 280],
#  ['ന്ന', 281],
#  ['▁ത', 282],
#  ['്ര', 283],
#  ['സ്', 284],
#  ['ട്ട', 285],
#  ['ങ്', 286],
#  ['▁ഇ', 287],
#  ['്യ', 288],
#  ['ായ', 289],
#  ['\u200b\u200b', 290],
#  ['▁അ', 291],
#  ['ല്\u200d', 292],
#  ['ള്\u200d', 293],
#  ['രി', 294],
#  ['പ്പ', 295],
#  ['▁ച', 296],
#  ['ങ്ങ', 297],
#  ['ുട', 298],
#  ['റ്റ', 299],
#  ['ിന്', 300],
#  ['▁ആ', 301],
#  ['ക്ക്', 302],
#  ['ച്ച', 303],
#  ['ിന', 304],
#  ['ുന്ന', 305],
#  ['▁എ', 306],
#  ['▁ബ', 307],
#  ['ായി', 308],
#  ['ാര', 309],
#  ['്ല', 310],
#  ['ണ്ട', 311],
#  ['▁ല', 312],
#  ['▁വി', 313],
#  ['ുമ', 314],
#  ['റെ', 315],
#  ['▁പു', 316],
#  ['തി', 317],
#  ['ുടെ', 318],
#  ['ാന', 319],
#  ['ാന്\u200d', 320],
#  ['▁ര', 321],
#  ['ന്ത്', 322],
#  ['ിക്ക', 323],
#  ['▁ട', 324],
#  ['ഞ്', 325],
#  ['▁റ', 326],
#  ['▁പ്ര', 327],
#  ['ത്ര', 328],
#  ['്റ്റ', 329],
#  ['മ്', 330],
#  ['യ്', 331],
#  ['ന്ന്', 332],
#  ['ുവ', 333],
#  ['ാര്\u200d', 334],
#  ['ടി', 335],
#  ['ന്ത്യ', 336],
#  ['▁ജ', 337],
#  ['▁ഇന്ത്യ', 338],
#  ['ുക', 339],
#  ['▁നി', 340],
#  ['▁ഗ', 341],
#  ['്\u200c', 342],
#  ['ച്\u200c', 343],
#  ['ച്ച്\u200c', 344],
#  ['ക്ഷ', 345],
#  ['തിയ', 346],
#  ['▁ഓ', 347],
#  ['രു', 348],
#  ['ത്തി', 349],
#  ['ാണ', 350],
#  ['ാം', 351],
#  ['▁ഒ', 352],
#  ['▁കോ', 353],
#  ['്വ', 354],
#  ['ുന്നു', 355],
#  ['▁ഫ', 356],
#  ['സ്റ്റ', 357],
#  ['▁ശ', 358],
#  ['ണ്\u200d', 359],
#  ['▁പോ', 360],
#  ['▁വീ', 361],
#  ['ിന്റെ', 362],
#  ['ിക', 363],
#  ['രാ', 364],
#  ['ിച്ച', 365],
#  ['▁ചി', 366],
#  ['▁ഉ', 367],
#  ['ിലെ', 368],
#  ['ങ്ങള്\u200d', 369],
#  ['▁പുറ', 370],
#  ['▁മാ', 371],
#  ['ടു', 372],
#  ['ാക്ക', 373],
#  ['▁ചിത്ര', 374],
#  ['▁പുതിയ', 375],
#  ['ില്ല', 376],
#  ['മ്ബ', 377],
#  ['ംഗ', 378],
#  ['ുമായി', 379],
#  ['സി', 380],
#  ['ത്തില്\u200d', 381],
#  ['▁ചെ', 382],
#  ['യില്\u200d', 383],
#  ['ുറ', 384],
#  ['▁ക്', 385],
#  ['േഷ', 386],
#  ['▁ദ', 387],
#  ['ത്ത്', 388],
#  ['നി', 389],
#  ['ിട്ട', 390],
#  ['ാല', 391],
#  ['▁ഏ', 392],
#  ['ഡ്', 393],
#  ['ന്ത', 394],
#  ['\u200b\u200b\u200b', 395],
#  ['ള്', 396],
#  ['ള്ള', 397],
#  ['യും', 398],
#  ['െന്ന്', 399],
#  ['യുടെ', 400],
#  ['വി', 401],
#  ['ദ്', 402],
#  ['▁യ', 403],
#  ['▁ധ', 404],
#  ['ിനെ', 405],
#  ['ങ്ക', 406],
#  ['ിയുടെ', 407],
#  ['ല്ല', 408],
#  ['മ്മ', 409],
#  ['▁ഹ', 410],
#  ['റ്റ്', 411],
#  ['▁സ്വ', 412],
#  ['ിയോ', 413],
#  ['▁ഡ', 414],
#  ['ഞ്ഞ', 415],
#  ['▁പി', 416],
#  ['▁ടീ', 417],
#  ['▁താര', 418],
#  ['വ്', 419],
#  ['വാ', 420],
#  ['ളി', 421],
#  ['രിക്ക', 422],
#  ['ുകള്\u200d', 423],
#  ['സ്\u200c', 424],
#  ['ട്ട്', 425],
#  ['ണി', 426],
#  ['▁സി', 427],
#  ['പ്പ്', 428],
#  ['▁ബാ', 429],
#  ['▁പുറത്ത', 430],
#  ['ണം', 431],
#  ['കര്\u200d', 432],
#  ['▁നേ', 433],
#  ['ാല്\u200d', 434],
#  ['▁മു', 435],
#  ['ോട', 436],
#  ['രെ', 437],
#  ['യി', 438],
#  ['▁ഐ', 439],
#  ['ലി', 440],
#  ['ങ്ങള', 441],
#  ['റി', 442],
#  ['ോര്\u200d', 443],
#  ['▁തി', 444],
#  ['മി', 445],
#  ['ങ്ങി', 446],
#  ['ിയില്\u200d', 447],
#  ['യം', 448],
#  ['▁സെ', 449],
#  ['▁ഇന്ത്യന്\u200d', 450],
#  ['ീസ്', 451],
#  ['സ്റ്റര്\u200d', 452],
#  ['ഞ്ച', 453],
#  ['▁കേ', 454],
#  ['▁മോ', 455],
#  ['▁സം', 456],
#  ['െടു', 457],
#  ['ിച്ച്\u200c', 458],
#  ['ാവ', 459],
#  ['ിട്ടു', 460],
#  ['▁വെ', 461],
#  ['▁തുട', 462],
#  ['▁നട', 463],
#  ['▁രാ', 464],
#  ['▁ഷ', 465],
#  ['▁ലോ', 466],
#  ['ന്ദ', 467],
#  ['ിലേ', 468],
#  ['ുള്ള', 469],
#  ['യ്ക്ക്', 470],
#  ['രം', 471],
#  ['▁പുറത്തുവ', 472],
#  ['രിച്ച', 473],
#  ['ിച്ചു', 474],
#  ['ാണ്', 475],
#  ['▁കൂ', 476],
#  ['▁രൂ', 477],
#  ['ട്ടി', 478],
#  ['ാപ', 479],
#  ['യ്യ', 480],
#  ['▁പുറത്തുവിട്ടു', 481],
#  ['ന്റ', 482],
#  ['നെ', 483],
#  ['ാക', 484],
#  ['ണ്ടും', 485],
#  ['▁പോസ്റ്റര്\u200d', 486],
#  ['ലിയ', 487],
#  ['▁കുറ', 488],
#  ['തു', 489],
#  ['▁കു', 490],
#  ['▁രൂപ', 491],
#  ['ഡിയോ', 492],
#  ['ണ്ട്', 493],
#  ['▁വില', 494],
#  ['▁ഭ', 495],
#  ['ദ്യ', 496],
#  ['ദ്ധ', 497],
#  ['▁ഗോ', 498],
#  ['▁ഒരു', 499],
#  ['ാനം', 500],
#  ['▁വീണ്ടും', 501],
#  ['▁വേ', 502],
#  ['▁സു', 503],
#  ['പി', 504],
#  ['ഴ്', 505],
#  ['▁സ്', 506],
#  ['ര്\u200dണ', 507],
#  ['ഫ്', 508],
#  ['▁വര്\u200d', 509],
#  ['ിലേക്ക്', 510],
#  ['രീ', 511],
#  ['ത്തെ', 512],
#  ['യര്\u200d', 513],
#  ['▁ഈ', 514],
#  ['▁കൊ', 515],
#  ['▁പരി', 516],
#  ['ട്ര', 517],
#  ['റിയ', 518],
#  ['ിനി', 519],
#  ['ുകള', 520],
#  ['▁അവ', 521],
#  ['ഷ്ട', 522],
#  ['▁പറ', 523],
#  ['ക്കി', 524],
#  ['ാര്യ', 525],
#  ['▁വിജ', 526],
#  ['സ്ഥ', 527],
#  ['ാക്കി', 528],
#  ['ഡി', 529],
#  ['തിരെ', 530],
#  ['മാ', 531],
#  ['ൈന', 532],
#  ['േശ', 533],
#  ['▁സൂ', 534],
#  ['▁വീഡിയോ', 535],
#  ['ന്റെ', 536],
#  ['ഗ്', 537],
#  ['ോണ', 538],
#  ['▁ബി', 539],
#  ['മായി', 540],
#  ['ന്\u200dറെ', 541],
#  ['ന്നു', 542],
#  ['ിവ', 543],
#  ['ക്\u200c', 544],
#  ['▁കാ', 545],
#  ['▁തോ', 546],
#  ['ത്തിന്', 547],
#  ['നം', 548],
#  ['്ബ', 549],
#  ['ര്\u200dക്ക', 550],
#  ['▁സ്റ്റ', 551],
#  ['ദിന', 552],
#  ['▁തീ', 553],
#  ['▁റെ', 554],
#  ['▁വൈ', 555],
#  ['്രീ', 556],
#  ['▁തിരിച്ച', 557],
#  ['ണ്', 558],
#  ['▁ചിത്രം', 559],
#  ['▁വ്യ', 560],
#  ['തെ', 561],
#  ['ാമ', 562],
#  ['ോള്\u200d', 563],
#  ['▁രാജ', 564],
#  ['കര', 565],
#  ['കു', 566],
#  ['ക്കെ', 567],
#  ['ന്ദ്ര', 568],
#  ['▁വാ', 569],
#  ['▁ടീമ', 570],
#  ['▁ഏക', 571],
#  ['ുന്നത്', 572],
#  ['▁മൂ', 573],
#  ['യെ', 574],
#  ['▁ഞ', 575],
#  ['▁ലോക', 576],
#  ['വും', 577],
#  ['\u200b\u200b\u200b\u200b', 578],
#  ['▁ചെയ്', 579],
#  ['കള്\u200d', 580],
#  ['ല്\u200dക', 581],
#  ['▁എന്ന', 582],
#  ['ഹി', 583],
#  ['▁പാ', 584],
#  ['▁മറ', 585],
#  ['ിയെ', 586],
#  ['▁തകര്\u200d', 587],
#  ['▁ക്യ', 588],
#  ['ജി', 589],
#  ['രുമ', 590],
#  ['▁കാണ', 591],
#  ['▁അന', 592],
#  ['▁നല്\u200dക', 593],
#  ['▁റില', 594],
#  ['▁ഏകദിന', 595],
#  ['റ്റി', 596],
#  ['▁കള', 597],
#  ['ിപ്പ', 598],
#  ['ിയും', 599],
#  ['▁ട്ര', 600],
#  ['ടെ', 601],
#  ['▁കി', 602],
#  ['▁ചെയ്യ', 603],
#  ['▁സ്വര്\u200dണ', 604],
#  ['▁ഇനി', 605],
#  ['▁ലീ', 606],
#  ['ൊരു', 607],
#  ['▁താരം', 608],
#  ['വുമായി', 609],
#  ['ര്യ', 610],
#  ['▁ന്', 611],
#  ['ിലും', 612],
#  ['▁വിപ', 613],
#  ['ാദ', 614],
#  ['▁ആദ്യ', 615],
#  ['▁നിര്\u200d', 616],
#  ['ാള', 617],
#  ['ന്ധ', 618],
#  ['▁വൈറ', 619],
#  ['▁പ്രിയ', 620],
#  ['ീസ', 621],
#  ['ോള', 622],
#  ['ോഷ', 623],
#  ['▁ഓസ', 624],
#  ['രുന്നു', 625],
#  ['ബി', 626],
#  ['പ്ര', 627],
#  ['രാജ', 628],
#  ['ക്കും', 629],
#  ['പ്പെ', 630],
#  ['ൊപ്പ', 631],
#  ['▁കോടി', 632],
#  ['േലിയ', 633],
#  ['▁കോഹ', 634],
#  ['▁വിമ', 635],
#  ['സ്റ്റ്', 636],
#  ['ത്തിന്റെ', 637],
#  ['ന്\u200dസ്', 638],
#  ['▁സിനി', 639],
#  ['ത്തിലെ', 640],
#  ['ടിയ', 641],
#  ['ച്ചു', 642],
#  ['ത്തിന', 643],
#  ['ത്തിയ', 644],
#  ['സം', 645],
#  ['▁മേ', 646],
#  ['പ്പര്\u200d', 647],
#  ['ീല', 648],
#  ['വില', 649],
#  ['▁പൊ', 650],
#  ['ംഗ്ല', 651],
#  ['▁ഇന്ന്', 652],
#  ['▁പര', 653],
#  ['▁സാ', 654],
#  ['വര്\u200d', 655],
#  ['ുമ്ബ', 656],
#  ['പ്പെടു', 657],
#  ['കള', 658],
#  ['്യം', 659],
#  ['▁അവസ', 660],
#  ['▁നേട്ട', 661],
#  ['ംഗ്', 662],
#  ['ത്സ', 663],
#  ['ങ്ക്', 664],
#  ['▁ലക്ഷ', 665],
#  ['▁റിലീസ്', 666],
#  ['▁സിനിമ', 667],
#  ['ട്', 668],
#  ['വേ', 669],
#  ['ോടെ', 670],
#  ['▁മെ', 671],
#  ['കന്\u200d', 672],
#  ['ക്കം', 673],
#  ['മാര്\u200d', 674],
#  ['▁ശ്രീ', 675],
#  ['▁സൂപ്പര്\u200d', 676],
#  ['സര്\u200d', 677],
#  ['▁മോഹ', 678],
#  ['▁ഏറ്റ', 679],
#  ['▁രണ്ട', 680],
#  ['▁വിജയ', 681],
#  ['ോഗ', 682],
#  ['ഹരി', 683],
#  ['ോട്ട', 684],
#  ['റില്\u200d', 685],
#  ['ുപ', 686],
#  ['ോട്', 687],
#  ['ര്\u200dശ', 688],
#  ['▁യുവ', 689],
#  ['▁ആരാ', 690],
#  ['▁റണ്\u200d', 691],
#  ['▁നിര', 692],
#  ['▁പുറത്ത്', 693],
#  ['ണ്ണ', 694],
#  ['ാതെ', 695],
#  ['▁ബോ', 696],
#  ['▁സുര', 697],
#  ['▁ഓഹരി', 698],
#  ['രമ', 699],
#  ['▁ജയ', 700],
#  ['▁സഹ', 701],
#  ['ങ്ങനെ', 702],
#  ['▁പ്രതി', 703],
#  ['ംബ', 704],
#  ['മെ', 705],
#  ['ഖ്യ', 706],
#  ['െയ്', 707],
#  ['▁ലൂ', 708],
#  ['ാള്\u200d', 709],
#  ['ിന്ന്', 710],
#  ['▁ആരാധ', 711],
#  ['ിക്കാന്\u200d', 712],
#  ['ിക്കുന്നു', 713],
#  ['ദി', 714],
#  ['എല്\u200d', 715],
#  ['മ്ബര', 716],
#  ['▁ചെയ്തു', 717],
#  ['▁കൈ', 718],
#  ['സ്ഥാന', 719],
#  ['ത്യ', 720],
#  ['ാരം', 721],
#  ['േഷ്', 722],
#  ['▁ഉപ', 723],
#  ['▁കെ', 724],
#  ['ഞ്ഞു', 725],
#  ['േഷന്\u200d', 726],
#  ['▁മോഹന്\u200d', 727],
#  ['രള', 728],
#  ['ശ്വ', 729],
#  ['താ', 730],
#  ['▁ബ്ര', 731],
#  ['ടുത്ത', 732],
#  ['▁വിവാ', 733],
#  ['▁പെ', 734],
#  ['ന്\u200dസ', 735],
#  ['▁▁', 736],
#  ['ന്റ്', 737],
#  ['മു', 738],
#  ['ഞ്ഞ്', 739],
#  ['ിക്കും', 740],
#  ['▁തോല്\u200d', 741],
#  ['▁റെക്ക', 742],
#  ['▁വേണ്ട', 743],
#  ['ശീല', 744],
#  ['ികള്\u200d', 745],
#  ['▁പിന്ന', 746],
#  ['▁ഖ', 747],
#  ['▁സമ', 748],
#  ['▁മുന്ന', 749],
#  ['▁നിന്ന്', 750],
#  ['കാ', 751],
#  ['ക്ട', 752],
#  ['ഴ്\u200c', 753],
#  ['ക്കു', 754],
#  ['▁ജയം', 755],
#  ['▁ഫൈന', 756],
#  ['സിഫ', 757],
#  ['▁കോട', 758],
#  ['▁ധോണ', 759],
#  ['▁ശേഷ', 760],
#  ['▁സ്\u200c', 761],
#  ['▁മത്സ', 762],
#  ['ീവ', 763],
#  ['മായ', 764],
#  ['രും', 765],
#  ['ോണി', 766],
#  ['▁ടീം', 767],
#  ['▁കേരള', 768],
#  ['▁മാര്\u200d', 769],
#  ['▁ലൂസിഫ', 770],
#  ['▁സ്വന്ത', 771],
#  ['േണ്ട', 772],
#  ['▁പദ്ധ', 773],
#  ['▁പരമ്ബര', 774],
#  ['▁മോഹന്\u200dല', 775],
#  ['\u200c്', 776],
#  ['ഗ്ര', 777],
#  ['ന്നും', 778],
#  ['ിയിലെ', 779],
#  ['▁വര്\u200dഷ', 780],
#  ['▁പരിശീല', 781],
#  ['▁സര്\u200dക്ക', 782],
#  ['ന്നെ', 783],
#  ['യിലെ', 784],
#  ['▁നഷ്ട', 785],
#  ['▁രാജ്യ', 786],
#  ['▁വ്യാപ', 787],
#  ['ഷ്', 788],
#  ['▁യു', 789],
#  ['തല്\u200d', 790],
#  ['ത്രം', 791],
#  ['▁ശേഷം', 792],
#  ['▁സ്റ്റില്\u200d', 793],
#  ['പാ', 794],
#  ['രംഭ', 795],
#  ['▁തെ', 796],
#  ['▁പേ', 797],
#  ['ക്ഷേ', 798],
#  ['ലക്ഷ', 799],
#  ['ത്തിറ', 800],
#  ['ന്ത്രി', 801],
#  ['ര്\u200dച്ച', 802],
#  ['ിക്കുന്ന', 803],
#  ['ടം', 804],
#  ['മെന്ന്', 805],
#  ['▁റെക്കോര്\u200d', 806],
#  ['▁സ്വര്\u200dണവില', 807],
#  ['മേ', 808],
#  ['രേ', 809],
#  ['ലയ', 810],
#  ['ലെ', 811],
#  ['ശ്', 812],
#  ['▁ടെ', 813],
#  ['▁സൗ', 814],
#  ['▁പറയ', 815],
#  ['▁വന്\u200d', 816],
#  ['സ്\u200cട്ര', 817],
#  ['▁അവസാന', 818],
#  ['സ്\u200cട്രേലിയ', 819],
#  ['▁കല', 820],
#  ['ത്തും', 821],
#  ['▁ധോണി', 822],
#  ['▁പുറത്തിറ', 823],
#  ['ായ്', 824],
#  ['▁ചാ', 825],
#  ['▁നീ', 826],
#  ['▁രോ', 827],
#  ['▁നാല', 828],
#  ['▁പോയ', 829],
#  ['▁ആര്\u200d', 830],
#  ['▁ക്രിക്ക', 831],
#  ['തമ', 832],
#  ['▁ജി', 833],
#  ['▁ജോ', 834],
#  ['ക്\u200cസ്', 835],
#  ['യ്ക്ക', 836],
#  ['സില്\u200d', 837],
#  ['▁വിപണ', 838],
#  ['▁ഉയര്\u200d', 839],
#  ['ാര്\u200dട്ട', 840],
#  ['▁ബാങ്ക്', 841],
#  ['▁രണ്ടാം', 842],
#  ['യു', 843],
#  ['ദേശ', 844],
#  ['മാര', 845],
#  ['▁ആര', 846],
#  ['▁കീ', 847],
#  ['▁മാറ്റ', 848],
#  ['ദേ', 849],
#  ['ബ്', 850],
#  ['ൂറ', 851],
#  ['▁റാ', 852],
#  ['▁റി', 853],
#  ['ാന്ത', 854],
#  ['▁ഗ്ര', 855],
#  ['▁സര്\u200d', 856],
#  ['▁വാര്യ', 857],
#  ['ിനെതിരെ', 858],
#  ['▁കേന്ദ്ര', 859],
#  ['ങ്ങള്\u200dക്ക്', 860],
#  ['ിലീ', 861],
#  ['▁അഭ', 862],
#  ['ഞ്ച്', 863],
#  ['ൂര്\u200d', 864],
#  ['▁സ്ഥ', 865],
#  ['▁രോഹി', 866],
#  ['▁എയര്\u200d', 867],
#  ['▁നടന്\u200d', 868],
#  ['▁ബാങ്ക', 869],
#  ['രിച്ച്\u200c', 870],
#  ['വു', 871],
#  ['▁ഡി', 872],
#  ['െട്ട', 873],
#  ['ോണ്\u200d', 874],
#  ['▁ക്ല', 875],
#  ['▁കാര്\u200d', 876],
#  ['▁തന്നെ', 877],
#  ['ടിച്ച്\u200c', 878],
#  ['▁പവ', 879],
#  ['▁നടി', 880],
#  ['രുന്ന', 881],
#  ['▁ഗാനം', 882],
#  ['▁ലോകക', 883],
#  ['▁തീരുമ', 884],
#  ['ങ്കില്\u200d', 885],
#  ['▁തുടക്കം', 886],
#  ['രിയ', 887],
#  ['▁എം', 888],
#  ['ൂട്ടി', 889],
#  ['▁ഇംഗ്ല', 890],
#  ['ങ്ങളുടെ', 891],
#  ['▁റണ്\u200dസ്', 892],
#  ['▁വൈറല്\u200d', 893],
#  ['▁സംസ്ഥാന', 894],
#  ['▁ഓസ്\u200cട്രേലിയ', 895],
#  ['▁\u200b', 896],
#  ['▁കട', 897],
#  ['ായിക', 898],
#  ['▁വനി', 899],
#  ['ൊപ്പം', 900],
#  ['▁പന്ത', 901],
#  ['▁മമ്മ', 902],
#  ['▁മൂന്ന', 903],
#  ['▁മോഹന്\u200dലാല്\u200d', 904],
#  ['ാസ', 905],
#  ['ഡിയ', 906],
#  ['ികള', 907],
#  ['▁സീ', 908],
#  ['▁കുട', 909],
#  ['▁തുറ', 910],
#  ['▁മിക', 911],
#  ['ങ്ങിയ', 912],
#  ['മ്ബ്യ', 913],
#  ['▁ഇന്\u200d', 914],
#  ['ഞ്ഞെടു', 915],
#  ['▁ഏറ്റവും', 916],
#  ['▁പുറത്തിറങ്ങി', 917],
#  ['ധാന', 918],
#  ['ഷ്യ', 919],
#  ['ുംബ', 920],
#  ['െയി', 921],
#  ['▁തിര', 922],
#  ['▁കൂടി', 923],
#  ['▁ലീഗ്', 924],
#  ['ക്ടര്\u200d', 925],
#  ['▁ഞാന്\u200d', 926],
#  ['▁വിവാഹ', 927],
#  ['ുമെന്ന്', 928],
#  ['ത്തിന്\u200dറെ', 929],
#  ['റ്', 930],
#  ['്രി', 931],
#  ['എസ്\u200c', 932],
#  ['▁ലീഗ', 933],
#  ['▁കണ്ട', 934],
#  ['ാക്കിയ', 935],
#  ['▁ചിത്രങ്ങള്\u200d', 936],
#  ['കന', 937],
#  ['ധി', 938],
#  ['നോ', 939],
#  ['▁ടി', 940],
#  ['▁ബെ', 941],
#  ['ടക്ക', 942],
#  ['േറ്റ', 943],
#  ['▁കാര', 944],
#  ['▁ക്വ', 945],
#  ['ജെ', 946],
#  ['രണ', 947],
#  ['റു', 948],
#  ['ാഗ', 949],
#  ['ാരി', 950],
#  ['ിനു', 951],
#  ['▁മൊ', 952],
#  ['▁റയ', 953],
#  ['ത്തു', 954],
#  ['ക്ഷേപ', 955],
#  ['▁അറിയ', 956],
#  ['▁ആരംഭ', 957],
#  ['▁ഒന്ന', 958],
#  ['▁പവന്', 959],
#  ['▁മറുപ', 960],
#  ['▁ചാമ്ബ്യ', 961],
#  ['▁സ്വന്തമ', 962],
#  ['▁ആരാധകര്\u200d', 963],
#  ['യോ', 964],
#  ['ഫ്\u200c', 965],
#  ['്യൂ', 966],
#  ['▁മി', 967],
#  ['▁ലു', 968],
#  ['ട്ടു', 969],
#  ['ാറ്റ', 970],
#  ['്ട്ര', 971],
#  ['▁മലയ', 972],
#  ['യുമായി', 973],
#  ['▁കോഹ്ല', 974],
#  ['▁വര്\u200dധ', 975],
#  ['▁കളിക്ക', 976],
#  ['▁സുരേഷ്', 977],
#  ['തീ', 978],
#  ['ാജ', 979],
#  ['രവ്', 980],
#  ['▁ആവ', 981],
#  ['▁ടോ', 982],
#  ['▁മീ', 983],
#  ['▁സേ', 984],
#  ['ക്സ്', 985],
#  ['ിറ്റ', 986],
#  ['ൊക്കെ', 987],
#  ['▁മുന്\u200d', 988],
#  ['▁ഇങ്ങനെ', 989],
#  ['ക്കെതിരെ', 990],
#  ['പ്പെടുത്ത', 991],
#  ['▁വാര്യര്\u200d', 992],
#  ['ബര്\u200d', 993],
#  ['േക്ക', 994],
#  ['▁ഐപി', 995],
#  ['▁നാണ', 996],
#  ['വാന്\u200d', 997],
#  ['ോട്ട്', 998],
#  ['▁ദിലീ', 999],
#  ['▁പട്ട', 1000],
#  ['▁വൈറല', 1001],
#  ['പ്പന്\u200d', 1002],
#  ['സിന്റെ', 1003],
#  ['▁ചെന്ന', 1004],
#  ['▁മത്സര', 1005],
#  ['▁ടീസര്\u200d', 1006],
#  ['▁മികച്ച', 1007],
#  ['ങ്ങളില്\u200d', 1008],
#  ['ധു', 1009],
#  ['ഴി', 1010],
#  ['എസ്', 1011],
#  ['▁താ', 1012],
#  ['ിനും', 1013],
#  ['▁ചില', 1014],
#  ['ഖ്യാപ', 1015],
#  ['▁കുതി', 1016],
#  ['▁സംവി', 1017],
#  ['▁കോണ്\u200d', 1018],
#  ['▁നായിക', 1019],
#  ['ുകളില്\u200d', 1020],
#  ['▁നിക്ഷേപ', 1021],
#  ['ാറ', 1022],
#  ['താര', 1023],
#  ['ധ്യ', 1024],
#  ['ലും', 1025],
#  ['▁ഇള', 1026],
#  ['▁നാ', 1027],
#  ['ളിവു', 1028],
#  ['ാനും', 1029],
#  ['ക്കുറ', 1030],
#  ['മാന്\u200d', 1031],
#  ['▁ബിജെ', 1032],
#  ['▁ക്യാര', 1033],
#  ['▁വിമാന', 1034],
#  ['▁പദ്ധതി', 1035],
#  ['▁മൂന്നാം', 1036],
#  ['യ്\u200c', 1037],
#  ['ാനി', 1038],
#  ['ീവന', 1039],
#  ['▁ഫെ', 1040],
#  ['▁സോ', 1041],
#  ['ക്കാര', 1042],
#  ['മില്ല', 1043],
#  ['▁സമ്മ', 1044],
#  ['▁വിപണി', 1045],
#  ['▁വെള്ള', 1046],
#  ['െങ്കില്\u200d', 1047],
#  ['▁തുടങ്ങി', 1048],
#  ['▁തോല്\u200dവി', 1049],
#  ['▁വിമര്\u200dശ', 1050],
#  ['▁പ്രഖ്യാപ', 1051],
#  ['▁മാര്\u200dച്ച്\u200c', 1052],
#  ['▁റെക്കോര്\u200dഡ്', 1053],
#  ['ശം', 1054],
#  ['ത്ഥ', 1055],
#  ['നും', 1056],
#  ['ച്ചി', 1057],
#  ['ന്\u200dഡ', 1058],
#  ['പ്പി', 1059],
#  ['പ്രീ', 1060],
#  ['ാത്ത', 1061],
#  ['▁അംബ', 1062],
#  ['▁ട്വ', 1063],
#  ['▁പ്ല', 1064],
#  ['▁ശ്ര', 1065],
#  ['ന്\u200dസെ', 1066],
#  ['ിട്ട്', 1067],
#  ['ുന്നത', 1068],
#  ['▁കിരീ', 1069],
#  ['▁മറിക', 1070],
#  ['▁വെളി', 1071],
#  ['▁കാണാം', 1072],
#  ['▁ലക്ഷം', 1073],
#  ['പ്പില്\u200d', 1074],
#  ['▁ചെന്നൈ', 1075],
#  ['▁വിജയലക്ഷ', 1076],
#  ['▁ക്വാര്\u200dട്ട', 1077],
#  ['▁ക്യാരക്ടര്\u200d', 1078],
#  ['▁ക്രിക്കറ്റ്', 1079],
#  ['▁തകര്\u200dപ്പന്\u200d', 1080],
#  ['തം', 1081],
#  ['ഭവ', 1082],
#  ['ഞ്ജ', 1083],
#  ['▁ലഭ', 1084],
#  ['▁ലൊ', 1085],
#  ['സിന്', 1086],
#  ['ൈറ്റ', 1087],
#  ['▁എസ്', 1088],
#  ['▁സൈന', 1089],
#  ['▁എന്ന്', 1090],
#  ['▁രോഹിത്', 1091],
#  ['▁ടീമില്\u200d', 1092],
#  ['▁സെന്\u200dസെ', 1093],
#  ['▁സര്\u200dക്കാര്\u200d', 1094],
#  ['ീമ', 1095],
#  ['ീയ', 1096],
#  ['ോദ', 1097],
#  ['▁ഇറ', 1098],
#  ['▁ജീ', 1099],
#  ['▁ജെ', 1100],
#  ['▁നെ', 1101],
#  ['യായി', 1102],
#  ['▁ഫുട', 1103],
#  ['▁കമ്ബ', 1104],
#  ['▁വലിയ', 1105],
#  ['ത്തോടെ', 1106],
#  ['▁ഓസീസ്', 1107],
#  ['▁റിപ്പ', 1108],
#  ['▁ലൊക്ക', 1109],
#  ['▁വാര്\u200d', 1110],
#  ['▁വിപണിയില്\u200d', 1111],
#  ['ലൈ', 1112],
#  ['ഴു', 1113],
#  ['സു', 1114],
#  ['ഡ്\u200c', 1115],
#  ['ീകര', 1116],
#  ['കുതി', 1117],
#  ['ഷന്\u200d', 1118],
#  ['▁നടപ', 1119],
#  ['▁നായ', 1120],
#  ['ക്കാന്\u200d', 1121],
#  ['▁ഫൈനല്\u200d', 1122],
#  ['▁കോണ്\u200dഗ്ര', 1123],
#  ['▁ലൊക്കേഷന്\u200d', 1124],
#  ['കെ', 1125],
#  ['കോ', 1126],
#  ['ഖല', 1127],
#  ['തക', 1128],
#  ['ബാ', 1129],
#  ['ഹു', 1130],
#  ['ൂര', 1131],
#  ['രായ', 1132],
#  ['റും', 1133],
#  ['ുമോ', 1134],
#  ['▁അത', 1135],
#  ['ക്രമ', 1136],
#  ['▁നില', 1137],
#  ['▁പോക', 1138],
#  ['ലില്\u200d', 1139],
#  ['െത്തി', 1140],
#  ['▁എന്ത', 1141],
#  ['▁കാണൂ', 1142],
#  ['ിച്ചത്', 1143],
#  ['▁വിക്ക', 1144],
#  ['▁ശ്രീശ', 1145],
#  ['▁അടുത്ത', 1146],
#  ['▁ഏകദിനം', 1147],
#  ['ോര്\u200dട്ട്', 1148],
#  ['▁ഇന്ത്യയില്\u200d', 1149],
#  ['▁ചിത്രത്തിലെ', 1150],
#  ['ഡോ', 1151],
#  ['പേ', 1152],
#  ['ലു', 1153],
#  ['ംഗള', 1154],
#  ['രീന', 1155],
#  ['ഷ്\u200c', 1156],
#  ['ാസം', 1157],
#  ['▁ഇത', 1158],
#  ['▁ലി', 1159],
#  ['ഡ്രി', 1160],
#  ['െയ്\u200c', 1161],
#  ['▁ചരി', 1162],
#  ['ഞ്ചുറ', 1163],
#  ['തീക്ഷ', 1164],
#  ['രാട്ട', 1165],
#  ['▁അര്\u200d', 1166],
#  ['▁എത്ത', 1167],
#  ['▁ഞെട്ട', 1168],
#  ['▁നോര്\u200d', 1169],
#  ['▁ബംഗ്ല', 1170],
#  ['ാകുന്നു', 1171],
#  ['▁നേട്ടം', 1172],
#  ['▁മൂന്ന്', 1173],
#  ['ുമ്ബോള്\u200d', 1174],
#  ['▁ഇന്ത്യക്ക്', 1175],
#  ['ലോ', 1176],
#  ['ൊണ', 1177],
#  ['ക്ത', 1178],
#  ['ച്ഛ', 1179],
#  ['▁കര', 1180],
#  ['▁ഫി', 1181],
#  ['ൂട്ട', 1182],
#  ['ന്ത്ര', 1183],
#  ['പ്രീം', 1184],
#  ['▁പിന്', 1185],
#  ['▁രണ്ട്', 1186],
#  ['പ്പോള്\u200d', 1187],
#  ['▁ബോളിവു', 1188],
#  ['ാക്കാന്\u200d', 1189],
#  ['▁സുപ്രീം', 1190],
#  ['പ്പെടുത്തി', 1191],
#  ['▁ഏകദിനത്തില്\u200d', 1192],
#  ['ൈസ', 1193],
#  ['ോമ', 1194],
#  ['ദ്ദ', 1195],
#  ['ശ്യ', 1196],
#  ['സ്ത', 1197],
#  ['്രാ', 1198],
#  ['▁മണ', 1199],
#  ['▁വള', 1200],
#  ['ആര്\u200d', 1201],
#  ['രുടെ', 1202],
#  ['ീര്\u200d', 1203],
#  ['▁റൊണ', 1204],
#  ['ങ്ങളെ', 1205],
#  ['▁ആര്യ', 1206],
#  ['▁എല്ല', 1207],
#  ['▁ഏപ്ര', 1208],
#  ['▁ക്രി', 1209],
#  ['നിക്ക്', 1210],
#  ['യന്\u200dസ്', 1211],
#  ['▁റാഞ്ച', 1212],
#  ['ണമെന്ന്', 1213],
#  ['മന്ത്രി', 1214],
#  ['▁തിരിച്ചടി', 1215],
#  ['സാ', 1216],
#  ['ലിശ', 1217],
#  ['സില', 1218],
#  ['▁ഇട', 1219],
#  ['▁ജൂ', 1220],
#  ['ന്നി', 1221],
#  ['രന്\u200d', 1222],
#  ['▁ദേശ', 1223],
#  ['▁ശതമ', 1224],
#  ['▁അഭിന', 1225],
#  ['ഞ്ചുറി', 1226],
#  ['പ്പിന്', 1227],
#  ['മ്ബന്\u200d', 1228],
#  ['▁കാര്യ', 1229],
#  ['▁റയല്\u200d', 1230],
#  ['ാര്\u200dത്ഥ', 1231],
#  ['▁പറഞ്ഞ്', 1232],
#  ['▁മുതല്\u200d', 1233],
#  ['്ട്രേലിയ', 1234],
#  ['ക്കുറിച്ച്\u200c', 1235],
#  ['▁ചിത്രത്തിന്റെ', 1236],
#  ['ചി', 1237],
#  ['ലം', 1238],
#  ['വെ', 1239],
#  ['ിലി', 1240],
#  ['ക്ഷി', 1241],
#  ['ോഷ്യ', 1242],
#  ['▁അനു', 1243],
#  ['▁ദിവ', 1244],
#  ['▁രംഗ', 1245],
#  ['ിയായി', 1246],
#  ['▁ഓസീസ', 1247],
#  ['▁കരീന', 1248],
#  ['▁നേരി', 1249],
#  ['ര്\u200dമ്മ', 1250],
#  ['ാള്\u200dഡോ', 1251],
#  ['േക്കും', 1252],
#  ['▁കോഹ്\u200c', 1253],
#  ['▁ഗോള്\u200d', 1254],
#  ['▁പാര്\u200d', 1255],
#  ['▁സോഷ്യ', 1256],
#  ['▁സിറ്റി', 1257],
#  ['ക്കുന്നു', 1258],
#  ['▁നല്\u200dകിയ', 1259],
#  ['▁പ്രതീക്ഷ', 1260],
#  ['▁സോഷ്യല്\u200d', 1261],
#  ['▁പരിശീലകന്\u200d', 1262],
#  ['ലീ', 1263],
#  ['െയ', 1264],
#  ['നവ്', 1265],
#  ['ഴ്സ', 1266],
#  ['▁ഉട', 1267],
#  ['▁തല', 1268],
#  ['▁നോ', 1269],
#  ['▁യാ', 1270],
#  ['▁യൂ', 1271],
#  ...]

# %%
ids = sp.encode("കൊച്ചി മെട്രോയുടെ")
print(ids)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# [3972, 671, 3191, 400]
